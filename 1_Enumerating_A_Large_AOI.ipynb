# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# This notebook takes an AOI from the directory `AOIs` and prepares SLC pairing (aka "enumeration") for submission to the Hyp3-ISCE2 API.
#
# There are two general steps:
#
# 1. Create a stack of SLCs from the associated frames covering an AOI.
# 2. Pair the SLCs (enumeration) for preparation to submit to the Hyp3 API (the actual submission is in the next notebook)
#
# For each steps, we serialize the data. Note, the first step can be used for multiple enumeration strategies. There is an important aspect to the "stack" generation above. A stack here represents *all* the available SLCs for a set of *connected* frames. Part of the work done in this notebook is to obtain collections of frames that are connected. If the frames are not connected, it is too difficult to generate. We use "AOI" to describe the initial area of interest e.g. "US CONUS" or "East Coast". We will also use the term "track-AOI" which here breaks up frames based on their connectivity. If a track is concave and there is a break in acquisition track/path, then we have to separate our enumeration along each connected component.

# %%
from s1_frame_enumerator import (get_s1_stack, 
                                 filter_s1_stack_by_geometric_coverage_per_pass, 
                                 get_global_s1_frames, 
                                 get_overlapping_s1_frames, 
                                 enumerate_dates, 
                                 frames2gdf, 
                                 enumerate_gunw_time_series,
                                 gdf2frames)
from shapely.geometry import Point
import geopandas as gpd
from rasterio.crs import CRS
import numpy as np
import matplotlib.pyplot as plt
import warnings
import json
import pandas as pd
import datetime
from tqdm import tqdm
from pathlib import Path
from itertools import starmap
import yaml
from data_model import enumParams

# %% [markdown]
# # Checklist
#
# Before you begin you should have:
#
# - [ ] An AOI as a geojson in `AOIs`. Requires the name to be specified as `<AOI_NAME>.geojson`.
# - [ ] A yaml for the enumeration parameteters. It will be serialized indefinitely in `enum_configs`.
#
# # Paramaters
#
# We also have `RECOMPUTE_STACKS` as acquiring the SLC metadata takes time.

# %%
YAML_FILE = 'enumeration_parameters.yml'
RECOMPUTE_STACKS = False

# %% [markdown]
# # Load Parameters

# %%
PARAMS = enumParams.from_yaml(YAML_FILE)
PARAMS.__dict__
# Out:
# {'temporal_baseline_days': [0, 180, 365],
#  'n_secondaries_per_reference': 3,
#  'aoi_name': 'conus_west_coast',
#  'n_seeds': 3,
#  'track_numbers': None,
#  'data_directory': PosixPath('out'),
#  'date_of_enum': datetime.date(2024, 4, 18),
#  'stack_dir': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3/stack'),
#  'enum_dir': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3/enum'),
#  'yaml_path': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3/enum_params_2024-04-18.yml'),
#  'weather_model': 'hrrr',
#  'month_constraints': None,
#  'exclusive_month_constraints': False,
#  'aoi_geojson_path': PosixPath('AOIs/conus_west_coast.geojson'),
#  'valid_date_ranges': None,
#  'enum_parent_dir': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3'),
#  'yaml_path_record': PosixPath('enum_configs/conus_west_coast_2024-04.yml')}

# %% [markdown]
# This serializes the data to `enum_configs` so that previous parameters can be tracked. Can also directly read an old file and simply remove this serialization.

# %%
yaml_record = PARAMS.to_yaml()
yaml_record
# Out:
# PosixPath('enum_configs/conus_west_coast_2024-04.yml')

# %% [markdown]
# # Load AOI

# %%
df_aoi = gpd.read_file(PARAMS.aoi_geojson_path)
# This ensures we only get the mainland part
df_aoi.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Get Frames overlapping AOI
#
# This first cell gets the spatially fixed frames overlapping the AOI and possibly the provided track numbers.

# %%
aoi_geo = df_aoi.geometry.unary_union
frames = get_overlapping_s1_frames(aoi_geo, track_numbers=PARAMS.track_numbers)
df_frames_all = frames2gdf(frames)
df_frames_all.head()
# Out:
#    frame_id hemisphere  track_number_min  track_number_max  \
# 0      1923       west                13                13
# 1      1924       west                13                13
# 2      1925       west                13                13
# 3      1926       west                13                13
# 4      1927       west                13                13
#
#                                             geometry
# 0  POLYGON Z ((-124.23953 48.85656 0.00000, -124....
# 1  POLYGON Z ((-124.50349 47.69977 0.00000, -124....
# 2  POLYGON Z ((-124.76600 46.54287 0.00000, -124....
# 3  POLYGON Z ((-125.02271 45.38540 0.00000, -124....
# 4  POLYGON Z ((-125.27406 44.22736 0.00000, -125....

# %% [markdown]
# Let's remove frames that have less than 25% overlap with our AOI. This ensures ISCE2 will have roughly enough area to process.

# %%
intersection_geo = df_frames_all.geometry.intersection(aoi_geo)
with warnings.catch_warnings():
    # yes, we are computing areas in lat/lon - that's ok at these latitudes
    warnings.simplefilter("ignore", category=UserWarning)
    percent_overlap = intersection_geo.area / df_frames_all.geometry.area
df_frames = df_frames_all[percent_overlap >= .1].reset_index(drop=True)
df_frames = df_frames.explode(index_parts=True)
frames = gdf2frames(df_frames)

# %%
fig, ax = plt.subplots()
df_aoi.geometry.boundary.plot(ax=ax)
df_frames_by_track = df_frames.dissolve(by='track_number_min').reset_index(drop=False)
df_frames_by_track.plot(ax=ax, 
                        column='track_number_min',
                        categorical=True,
                        alpha=.25,
                        #legend=True
                       )
xmin, ymin, xmax, ymax = df_frames_by_track.total_bounds
ax.set_xlim(xmin - 1, xmax + 1)
ax.set_ylim(ymin - 1, ymax + 1)
# Out:
# (30.78421186522863, 50.82910087318885)

# %% [markdown]
# # Get Stack from Frame
#
# Here a "stack" refers to obtaining all the SLC's that cover spatially fixed frames on a given track (you can only do InSAR with a fixed SAR geometry! i.e. on a fixed track). See [frame-enumerator](https://github.com/ACCESS-Cloud-Based-InSAR/s1-frame-enumerator) repository for more details about our terminology related to stacks, frames and enumeration of interferometric pairs.
#
# We will serialize each stack to a geojson. If `RECOMPUTE_STACKS` is `True`, then will overwrite existing stacks to retreive the most-up-to-date stack. Our generation of a stack relies on simply hitting the ASF API through its python [library](https://github.com/asfadmin/Discovery-asf_search).
#
# Creating a workflow that "updates" an existing serialized stack is beyond the scope of this notebook, and quite frankly, not recommended, as such would require lots of book-keeping that would significantly bloat this notebook and the enumeration code. Acquiring multiple stacks covering a US coast generated in less than 30 minutes seems reasonable. Also, since the serialization of each stack is done, the stack data can be reused without re-running it.

# %%
all_tracks = df_frames.track_number_min.unique().tolist()
all_tracks[:3]
# Out:
# [34, 41, 143]

# %% [markdown]
# An important book-keeping piece is that we are going to group the frames by track *and* by its connected component into what we will also call a "track-AOIs". These "track-AOIs" are essential for enumeration (*we cannot enumerate over disconnected areas*, see the [`s1-frame-enumerator`](https://github.com/ACCESS-Cloud-Based-InSAR/s1_frame_enumerator)).
#
# The groups also are how we group jobs for accounting. A "track-AOI" is simply a contiguous set of frames that overlap our AOI. Note that a single track can become disconnected based on our AOI (this is caused by concavity in an AOI or when the AOI is itself disconnected as in the case of multiple islands). We will name these track AOIs using the convention `track{N}` where `N` is the track number for the first connected component and `track{N}-_{index}`. For example, if we have track 23 with multiple connected components, this would look like `track23, track23_1, ...`.
#
# **Warning**: We have the initial "AOI" which refers to a general area of interest for a science use case such as "US CONUS" or "Tibet" and now we *also* are grouping frames into "track-AOIs" to ensure that our enumeration is over a connected set of frames.
#
# Below we create dictionary with key `track_AOI_ID` and value a list of frames within that area. A frame is simply a data container

# %%
def id_formatter(row: pd.Series):
    """Returns 'track<track_number>' for first instance and then 'track<track_number>_k' for each subsequent k index"""
    if row['level_1']:
        return f"track{row['track_number_min']}_{row['level_1']}"
    else:
        return f"track{row['track_number_min']}"

df_track_aois = df_frames_by_track.explode().reset_index(drop=False)
df_track_aois['track_aoi_id'] = df_track_aois.apply(id_formatter, axis=1)
df_track_aois.head()
# Out:
# /var/folders/0p/d5x2m4tx5kg1246bplsvyfyh0000gq/T/ipykernel_27823/2628663778.py:8: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   df_track_aois = df_frames_by_track.explode().reset_index(drop=False)
#    level_0  level_1  track_number_min  frame_id hemisphere  track_number_max  \
# 0        0        0                34      5137       west                34
# 1        0        1                34      5137       west                34
# 2        1        0                41      6296       west                41
# 3        2        0               143     22285       west               143
#
#                                             geometry track_aoi_id
# 0  POLYGON Z ((-97.31343 29.68953 0.00000, -97.31...      track34
# 1  POLYGON Z ((-98.52027 35.01507 0.00000, -98.55...    track34_1
# 2  POLYGON Z ((-98.45807 34.61151 0.00000, -98.42...      track41
# 3  POLYGON Z ((-97.45894 29.23392 0.00000, -97.23...     track143

# %%
track2frames = {row['track_aoi_id']: [f for f in frames 
                                      if row['track_number_min'] in f.track_numbers 
                                      if row['geometry'].intersects(f.frame_geometry)
                       ] 
                for _, row in df_track_aois.iterrows()}

keys = list(track2frames.keys())
track2frames[keys[0]]
# Out:
# [S1Frame(frame_id=5137, hemisphere='west', track_numbers=[34], frame_geometry=<POLYGON Z ((-97.236 29.341 0, -97.313 29.69 0, -97.311 29.69 0, -97.461 30....>, footprint_geometry=<POLYGON ((-97.314 29.689, -97.311 29.69, -97.497 30.522, -96.611 30.67, -96...>)]

# %% [markdown]
# For each `track_aoi_id`, we save the stack as `track{N}-{AOI_NAME}`, hopefully the multiple use of "AOIs" is clear.

# %%
track_log = tqdm(total=0, position=0, bar_format='{desc}')

def get_s1_stack_and_serialize(track_aoi_id: str, frames: list, recompute_stack=RECOMPUTE_STACKS):
    if not frames:
        warnings.warn('No frames submitted')
        return
    track_stack_path = PARAMS.stack_dir / f'{track_aoi_id}-{PARAMS.aoi_name}.geojson'
    track_log.set_description_str(f'Current track: {track_stack_path}')
    if track_stack_path.exists() and (not recompute_stack):
        return track_stack_path
    ## MODIFY THIS IF YOU WANT MORE OR LESS PAIRINGS; would not modify `minimum_coverage_ratio_per_frame` because 
    ## ISCE2 needs minimum amount of data to process; but per pass allows for more or less coverage
    df_stack = get_s1_stack(frames, minimum_coverage_ratio_per_frame=.2, minimum_coverage_ratio_per_pass=.8)
    if df_stack.empty:
        warnings.warn(f'Empty stack - still writing for records - check {track_aoi_id} on asf_search')
    df_stack.to_file(track_stack_path, driver='GeoJSON')
    return track_stack_path

# %%
input_frame_data = list(track2frames.items())
stack_paths = list(starmap(get_s1_stack_and_serialize, tqdm(input_frame_data)))
# Out:
# Current track: out/nisar_sample__tb_0-180-365__neigh_3-1-1/stack/track34-nisar_sample.geojson
#
# Downloading stack from 1 frame geometries:   0%| | 0/1 [00:00<?, ?it/s
#
# Downloading stack from 1 frame geometries: 100%|█| 1/1 [00:05<00:00,
#
# Current track: out/nisar_sample__tb_0-180-365__neigh_3-1-1/stack/track34_1-nisar_sample.geojson
#
# Downloading stack from 2 frame geometries:   0%| | 0/2 [00:00<?, ?it/s
#
# Downloading stack from 2 frame geometries:  50%|▌| 1/2 [00:03<00:03,
#
# Downloading stack from 2 frame geometries: 100%|█| 2/2 [00:07<00:00,
#
# Current track: out/nisar_sample__tb_0-180-365__neigh_3-1-1/stack/track41-nisar_sample.geojson
#
# Downloading stack from 1 frame geometries:   0%| | 0/1 [00:00<?, ?it/s
#
# Downloading stack from 1 frame geometries: 100%|█| 1/1 [00:00<00:00,
# /Users/cmarshak/bekaert-team/s1-frame-enumerator/src/s1_frame_enumerator/s1_stack.py:183: UserWarning: There were no results returned
#   warn('There were no results returned', category=UserWarning)
# /var/folders/0p/d5x2m4tx5kg1246bplsvyfyh0000gq/T/ipykernel_27823/845062104.py:13: UserWarning: Empty stack - still writing for records - check track41 on asf_search
#   warnings.warn(f'Empty stack - still writing for records - check {track_aoi_id} on asf_search')
# /Users/cmarshak/miniforge3/envs/aria_hyp3_env/lib/python3.12/site-packages/geopandas/io/file.py:633: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#
# Current track: out/nisar_sample__tb_0-180-365__neigh_3-1-1/stack/track143-nisar_sample.geojson
#
# Downloading stack from 1 frame geometries:   0%| | 0/1 [00:00<?, ?it/s
#
# Downloading stack from 1 frame geometries: 100%|█| 1/1 [00:03<00:00,
#
# 100%|███████████████████████████████████| 4/4 [00:17<00:00,  4.38s/it]

# %% [markdown]
# # Generate IFG Pairs
#
# The basic enumeration is we loop through all available `min_temporal_baseline`'s and `n_secondary_per_reference` provided. Note you can provide multiple of each and they are `zip`ped up.
#
# There are additional parameters too. We can perform an independent enumeration of pairs (if `MONTH_CONSTRAINTS` is non-empty or not `None`), filtering the stack based on those months provided in the enumeration parameters. This allows us to select months with likely high-coherence.
#
# It's important to note that this is *not* part of the enumeration library (yet?) as the application of enumeration is ever evolving and often requires tweaks that are beyond the scope of a given libraries function. Although the functions appear quite long, a lot of the code is meant to assist with serializaiton as the pairings need to be recorded for (a) inspection by the Hyp3 submission and (b) for later inspection should reprocessing be required.

# %%
df_stack_sample = gpd.read_file(stack_paths[0])
df_stack_sample.head()
# Out:
#                                               slc_id  \
# 0  S1A_IW_SLC__1SDV_20160412T002604_20160412T0026...
# 1  S1A_IW_SLC__1SDV_20160412T002631_20160412T0026...
# 2  S1A_IW_SLC__1SDV_20160927T002612_20160927T0026...
# 3  S1A_IW_SLC__1SDV_20160927T002640_20160927T0027...
# 4  S1A_IW_SLC__1SDV_20161009T002612_20161009T0026...
#
#                   start_time                  stop_time  \
# 0  2016-04-12T00:26:04+00:00  2016-04-12T00:26:33+00:00
# 1  2016-04-12T00:26:31+00:00  2016-04-12T00:26:59+00:00
# 2  2016-09-27T00:26:12+00:00  2016-09-27T00:26:42+00:00
# 3  2016-09-27T00:26:40+00:00  2016-09-27T00:27:07+00:00
# 4  2016-10-09T00:26:12+00:00  2016-10-09T00:26:42+00:00
#
#                                                  url  track_number  \
# 0  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            34
# 1  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            34
# 2  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            34
# 3  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            34
# 4  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            34
#
#   polarization  orbit beam_mode   size_gb flight_direction  \
# 0        VV+VH  10781        IW  4.692646        ASCENDING
# 1        VV+VH  10781        IW  4.849465        ASCENDING
# 2        VV+VH  13231        IW  4.775260        ASCENDING
# 3        VV+VH  13231        IW  4.919882        ASCENDING
# 4        VV+VH  13406        IW  4.764586        ASCENDING
#
#    stack_repeat_pass_id     repeat_pass_timestamp  \
# 0                     0 2016-04-12 00:00:00+00:00
# 1                     0 2016-04-12 00:00:00+00:00
# 2                     1 2016-09-27 00:00:00+00:00
# 3                     1 2016-09-27 00:00:00+00:00
# 4                     2 2016-10-09 00:00:00+00:00
#
#                                             geometry
# 0  POLYGON ((-97.29732 29.63038, -96.89981 27.832...
# 1  POLYGON ((-97.64256 31.17702, -97.26533 29.495...
# 2  POLYGON ((-97.29745 29.63274, -96.89984 27.834...
# 3  POLYGON ((-97.64256 31.17889, -97.26541 29.497...
# 4  POLYGON ((-97.29813 29.63279, -96.90047 27.834...

# %%
IFG_COLUMNS = ['reference', 'secondary', 'reference_date', 'secondary_date', 'frame_id', 'geometry']
def encode_dataframe_for_serialization(df_ifg: gpd.GeoDataFrame) -> gpd.GeoDataFrame:
    df_ifg['reference_date'] = df_ifg['reference_date'].dt.date.astype(str)
    df_ifg['secondary_date'] = df_ifg['secondary_date'].dt.date.astype(str)
    
    df_ifg['reference'] = df_ifg['reference'].map(lambda l: ' '.join(l))
    df_ifg['secondary'] = df_ifg['secondary'].map(lambda l: ' '.join(l))
    
    df_ifg.crs = CRS.from_epsg(4326)
    return df_ifg  


def enumerate_one_stack(stack_path: Path,
                        temporal_baselines_days: int, 
                        neighbors: int | list[int],
                        n_init_seeds: int,
                        month_constraints: list,
                        exclusive_month_constraints: bool,
                        valid_date_ranges: list):
    neighbors_lst = neighbors if isinstance(neighbors, list) else [neighbors] * len(temporal_baselines_days)
    
    df_stack = gpd.read_file(stack_path)
    
    stack_path_stem = stack_path.stem
    track_aoi_key, aoi_name = stack_path_stem.split('-')
    
    frames = track2frames[track_aoi_key]
    enum_data_path_track_aoi = PARAMS.enum_dir / f'{track_aoi_key}-{aoi_name}.geojson'
    
    # We prepare an empty output dataframe in case any steps yeild empty frames
    df_ifg = gpd.GeoDataFrame(columns=IFG_COLUMNS)
    df_ifg.crs = CRS.from_epsg(4326)

    all_data = []
    # Only enumerate if stack non-empty
    if not df_stack.empty:
        # We will loop through constraints and month constraints if desired
        month_constraints_enumeration = [] if exclusive_month_constraints else [False]
        if month_constraints:
            month_constraints_enumeration.append(True)            
        for constraint in month_constraints_enumeration:
            df_stack_temp = df_stack.copy()
            if constraint:
                months_in_stack = pd.to_datetime(df_stack_temp.repeat_pass_timestamp).dt.month
                ind = months_in_stack.isin(month_constraints)
                df_stack_temp = df_stack_temp[ind].reset_index(drop=True)
            if valid_date_ranges is not None:
                valid_date_ranges_ts = [(pd.to_datetime(t_0), pd.to_datetime(t_1))
                                        for (t_0, t_1) in valid_date_ranges]
                inds = [((df_stack_temp.repeat_pass_timestamp >= t_0) & (df_stack_temp.repeat_pass_timestamp <= t_1)) 
                        for (t_0, t_1) in valid_date_ranges_ts]
                ind = np.logical_or.reduce(inds)
                df_stack_temp = df_stack_temp[ind].reset_index(drop=True)
            if not df_stack_temp.empty:
                for neigh, tb in zip(neighbors_lst, temporal_baselines_days):
                    data = enumerate_gunw_time_series(df_stack_temp, 
                                                      tb, 
                                                      n_secondary_scenes_per_ref=neigh,
                                                      frames=frames,
                                                      n_init_seeds=n_init_seeds,
                                                      )
                    all_data += data

    # There are situations when the stack is non-empty and we have no pairs (literally one pass - see track 55)
    if all_data:
        df_ifg = gpd.GeoDataFrame(all_data)
        df_ifg = df_ifg.drop_duplicates(subset=['reference_date', 
                                                'secondary_date', 
                                                'frame_id']).reset_index(drop=True)
        df_ifg = encode_dataframe_for_serialization(df_ifg)
        
        # Write some important parameters
        df_ifg['track_aoi_key'] = track_aoi_key
        df_ifg['aoi_name'] = aoi_name
    
    df_ifg.to_file(enum_data_path_track_aoi, driver='GeoJSON')
    return enum_data_path_track_aoi

# %%
def enumerate_one_stack_p(stack_path: Path):
    return enumerate_one_stack(stack_path,
                               temporal_baselines_days=PARAMS.temporal_baseline_days,
                               neighbors=PARAMS.n_secondaries_per_reference,
                               n_init_seeds=PARAMS.n_seeds,
                               exclusive_month_constraints=PARAMS.exclusive_month_constraints,
                               month_constraints=PARAMS.month_constraints,
                               valid_date_ranges=PARAMS.valid_date_ranges
                              )

# %%
ifg_data_paths = list(map(enumerate_one_stack_p, tqdm(stack_paths[:])))
# Out:
#   0%|                                           | 0/4 [00:00<?, ?it/s]
#
# Date Pairs:   0%|                             | 0/642 [00:00<?, ?it/s]
#
# Date Pairs:   2%|▎                   | 10/642 [00:00<00:06, 99.40it/s]
#
# Date Pairs:   3%|▌                   | 20/642 [00:00<00:06, 98.31it/s]
#
# Date Pairs:   5%|▉                   | 31/642 [00:00<00:06, 99.53it/s]
#
# Date Pairs:   7%|█▏                 | 42/642 [00:00<00:05, 100.41it/s]
#
# Date Pairs:   8%|█▌                 | 53/642 [00:00<00:05, 101.73it/s]
#
# Date Pairs:  10%|█▉                 | 64/642 [00:00<00:05, 102.99it/s]
#
# Date Pairs:  12%|██▏                | 75/642 [00:00<00:05, 101.76it/s]
#
# Date Pairs:  13%|██▌                | 86/642 [00:00<00:05, 102.59it/s]
#
# Date Pairs:  15%|██▊                | 97/642 [00:00<00:05, 103.42it/s]
#
# Date Pairs:  17%|███               | 108/642 [00:01<00:05, 103.38it/s]
#
# Date Pairs:  19%|███▎              | 119/642 [00:01<00:05, 104.03it/s]
#
# Date Pairs:  20%|███▋              | 130/642 [00:01<00:04, 103.56it/s]
#
# Date Pairs:  22%|███▉              | 141/642 [00:01<00:04, 104.21it/s]
#
# Date Pairs:  24%|████▎             | 152/642 [00:01<00:04, 103.29it/s]
#
# Date Pairs:  25%|████▊              | 163/642 [00:01<00:05, 87.16it/s]
#
# Date Pairs:  27%|█████              | 173/642 [00:01<00:05, 90.23it/s]
#
# Date Pairs:  29%|█████▍             | 184/642 [00:01<00:04, 93.84it/s]
#
# Date Pairs:  30%|█████▊             | 195/642 [00:01<00:04, 97.11it/s]
#
# Date Pairs:  32%|██████             | 206/642 [00:02<00:04, 99.25it/s]
#
# Date Pairs:  34%|██████            | 217/642 [00:02<00:04, 101.15it/s]
#
# Date Pairs:  36%|██████▍           | 228/642 [00:02<00:04, 102.29it/s]
#
# Date Pairs:  37%|██████▋           | 239/642 [00:02<00:03, 102.52it/s]
#
# Date Pairs:  39%|███████           | 250/642 [00:02<00:03, 102.34it/s]
#
# Date Pairs:  41%|███████▎          | 261/642 [00:02<00:03, 102.91it/s]
#
# Date Pairs:  42%|███████▋          | 272/642 [00:02<00:03, 102.94it/s]
#
# Date Pairs:  44%|███████▉          | 283/642 [00:02<00:03, 102.86it/s]
#
# Date Pairs:  46%|████████▏         | 294/642 [00:02<00:03, 102.19it/s]
#
# Date Pairs:  48%|████████▌         | 305/642 [00:03<00:03, 101.71it/s]
#
# Date Pairs:  49%|████████▊         | 316/642 [00:03<00:03, 101.76it/s]
#
# Date Pairs:  51%|█████████▏        | 327/642 [00:03<00:03, 101.68it/s]
#
# Date Pairs:  53%|█████████▍        | 338/642 [00:03<00:02, 101.83it/s]
#
# Date Pairs:  54%|█████████▊        | 349/642 [00:03<00:02, 102.48it/s]
#
# Date Pairs:  56%|██████████        | 360/642 [00:03<00:02, 102.50it/s]
#
# Date Pairs:  58%|██████████▍       | 371/642 [00:03<00:02, 103.05it/s]
#
# Date Pairs:  60%|██████████▋       | 382/642 [00:03<00:02, 102.87it/s]
#
# Date Pairs:  61%|███████████       | 393/642 [00:03<00:02, 103.31it/s]
#
# Date Pairs:  63%|███████████▎      | 404/642 [00:03<00:02, 103.14it/s]
#
# Date Pairs:  65%|███████████▋      | 415/642 [00:04<00:02, 103.39it/s]
#
# Date Pairs:  66%|███████████▉      | 426/642 [00:04<00:02, 103.99it/s]
#
# Date Pairs:  68%|████████████▎     | 437/642 [00:04<00:01, 104.20it/s]
#
# Date Pairs:  70%|████████████▌     | 448/642 [00:04<00:01, 105.38it/s]
#
# Date Pairs:  71%|████████████▊     | 459/642 [00:04<00:01, 104.69it/s]
#
# Date Pairs:  73%|█████████████▏    | 470/642 [00:04<00:01, 105.32it/s]
#
# Date Pairs:  75%|█████████████▍    | 481/642 [00:04<00:01, 105.46it/s]
#
# Date Pairs:  77%|█████████████▊    | 492/642 [00:04<00:01, 105.08it/s]
#
# Date Pairs:  78%|██████████████    | 503/642 [00:04<00:01, 105.03it/s]
#
# Date Pairs:  80%|██████████████▍   | 514/642 [00:05<00:01, 103.44it/s]
#
# Date Pairs:  82%|██████████████▋   | 525/642 [00:05<00:01, 101.66it/s]
#
# Date Pairs:  83%|███████████████   | 536/642 [00:05<00:01, 101.79it/s]
#
# Date Pairs:  85%|███████████████▎  | 547/642 [00:05<00:00, 102.43it/s]
#
# Date Pairs:  87%|███████████████▋  | 558/642 [00:05<00:00, 102.69it/s]
#
# Date Pairs:  89%|███████████████▉  | 569/642 [00:05<00:00, 102.70it/s]
#
# Date Pairs:  90%|████████████████▎ | 580/642 [00:05<00:00, 103.63it/s]
#
# Date Pairs:  92%|████████████████▌ | 591/642 [00:05<00:00, 103.79it/s]
#
# Date Pairs:  94%|█████████████████▊ | 602/642 [00:05<00:00, 98.60it/s]
#
# Date Pairs:  95%|██████████████████▏| 613/642 [00:06<00:00, 99.50it/s]
#
# Date Pairs:  97%|█████████████████▍| 624/642 [00:06<00:00, 100.54it/s]
#
# Date Pairs: 100%|██████████████████| 642/642 [00:06<00:00, 101.78it/s]
#
#
# Date Pairs:   0%|                              | 0/45 [00:00<?, ?it/s]
#
# Date Pairs:  24%|████▉               | 11/45 [00:00<00:00, 104.41it/s]
#
# Date Pairs:  49%|█████████▊          | 22/45 [00:00<00:00, 103.07it/s]
#
# Date Pairs:  73%|██████████████▋     | 33/45 [00:00<00:00, 104.04it/s]
#
# Date Pairs: 100%|████████████████████| 45/45 [00:00<00:00, 104.15it/s]
#
#
# Date Pairs:   0%|                              | 0/19 [00:00<?, ?it/s]
#
# Date Pairs: 100%|████████████████████| 19/19 [00:00<00:00, 102.26it/s]
#
#  25%|████████▊                          | 1/4 [00:07<00:21,  7.22s/it]
# Date Pairs:  97%|██████████████████▍| 698/717 [00:14<00:00, 48.64it/s]
#
# Date Pairs:  98%|██████████████████▋| 703/717 [00:14<00:00, 48.51it/s]
#
# Date Pairs:  99%|██████████████████▊| 708/717 [00:14<00:00, 48.58it/s]
#
# Date Pairs: 100%|███████████████████| 717/717 [00:15<00:00, 47.75it/s]
#
#
# Date Pairs:   0%|                              | 0/48 [00:00<?, ?it/s]
#
# Date Pairs:  10%|██▎                   | 5/48 [00:00<00:00, 47.90it/s]
#
# Date Pairs:  21%|████▍                | 10/48 [00:00<00:00, 48.57it/s]
#
# Date Pairs:  31%|██████▌              | 15/48 [00:00<00:00, 45.01it/s]
#
# Date Pairs:  42%|████████▊            | 20/48 [00:00<00:00, 45.99it/s]
#
# Date Pairs:  52%|██████████▉          | 25/48 [00:00<00:00, 45.81it/s]
#
# Date Pairs:  62%|█████████████▏       | 30/48 [00:00<00:00, 46.47it/s]
#
# Date Pairs:  73%|███████████████▎     | 35/48 [00:00<00:00, 46.81it/s]
#
# Date Pairs:  83%|█████████████████▌   | 40/48 [00:00<00:00, 46.70it/s]
#
# Date Pairs: 100%|█████████████████████| 48/48 [00:01<00:00, 46.78it/s]
#
#
# Date Pairs:   0%|                              | 0/21 [00:00<?, ?it/s]
#
# Date Pairs:  24%|█████▏                | 5/21 [00:00<00:00, 47.76it/s]
#
# Date Pairs:  48%|██████████           | 10/21 [00:00<00:00, 48.27it/s]
#
# Date Pairs:  71%|███████████████      | 15/21 [00:00<00:00, 48.31it/s]
#
# Date Pairs: 100%|█████████████████████| 21/21 [00:00<00:00, 48.19it/s]
#
#  50%|█████████████████▌                 | 2/4 [00:24<00:25, 12.93s/it]/Users/cmarshak/miniforge3/envs/aria_hyp3_env/lib/python3.12/site-packages/geopandas/io/file.py:633: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#
#
# Date Pairs:   0%|                            | 0/1269 [00:00<?, ?it/s]
#
# Date Pairs:   1%|▏                  | 10/1269 [00:00<00:13, 92.89it/s]
#
# Date Pairs:   2%|▎                  | 20/1269 [00:00<00:13, 93.50it/s]
#
# Date Pairs:   2%|▍                  | 30/1269 [00:00<00:13, 94.56it/s]
#
# Date Pairs:   3%|▌                  | 40/1269 [00:00<00:13, 89.71it/s]
#
# Date Pairs:   4%|▋                  | 50/1269 [00:00<00:13, 92.30it/s]
#
# Date Pairs:   5%|▉                  | 60/1269 [00:00<00:13, 92.58it/s]
#
# Date Pairs:   6%|█                  | 70/1269 [00:00<00:12, 94.14it/s]
#
# Date Pairs:   6%|█▏                 | 80/1269 [00:00<00:12, 95.33it/s]
#
# Date Pairs:   7%|█▎                 | 90/1269 [00:00<00:12, 94.36it/s]
#
# Date Pairs:   8%|█▍                | 100/1269 [00:01<00:12, 95.34it/s]
#
# Date Pairs:   9%|█▌                | 110/1269 [00:01<00:12, 94.97it/s]
#
# Date Pairs:   9%|█▋                | 120/1269 [00:01<00:12, 94.60it/s]
# Date Pairs:  65%|███████████▋      | 820/1269 [00:08<00:04, 92.79it/s]
#
# Date Pairs:  65%|███████████▊      | 830/1269 [00:08<00:04, 92.40it/s]
#
# Date Pairs:  66%|███████████▉      | 840/1269 [00:08<00:04, 92.74it/s]
#
# Date Pairs:  67%|████████████      | 850/1269 [00:09<00:04, 92.08it/s]
#
# Date Pairs:  68%|████████████▏     | 860/1269 [00:09<00:04, 92.49it/s]
#
# Date Pairs:  69%|████████████▎     | 870/1269 [00:09<00:04, 92.71it/s]
#
# Date Pairs:  69%|████████████▍     | 880/1269 [00:09<00:04, 92.61it/s]
#
# Date Pairs:  70%|████████████▌     | 890/1269 [00:09<00:04, 92.98it/s]
#
# Date Pairs:  71%|████████████▊     | 900/1269 [00:09<00:03, 93.25it/s]
#
# Date Pairs:  72%|████████████▉     | 910/1269 [00:09<00:03, 93.60it/s]
#
# Date Pairs:  72%|█████████████     | 920/1269 [00:09<00:03, 93.71it/s]
#
# Date Pairs:  73%|█████████████▏    | 930/1269 [00:09<00:03, 93.96it/s]
#
# Date Pairs:  74%|█████████████▎    | 940/1269 [00:10<00:03, 94.52it/s]
#
# Date Pairs:  75%|█████████████▍    | 950/1269 [00:10<00:03, 94.93it/s]
#
# Date Pairs:  76%|█████████████▌    | 960/1269 [00:10<00:03, 95.35it/s]
#
# Date Pairs:  76%|█████████████▊    | 970/1269 [00:10<00:03, 95.44it/s]
#
# Date Pairs:  77%|█████████████▉    | 980/1269 [00:10<00:03, 91.23it/s]
#
# Date Pairs:  78%|██████████████    | 990/1269 [00:10<00:03, 92.58it/s]
#
# Date Pairs:  79%|█████████████▍   | 1000/1269 [00:10<00:02, 92.30it/s]
#
# Date Pairs:  80%|█████████████▌   | 1010/1269 [00:10<00:02, 91.88it/s]
#
# Date Pairs:  80%|█████████████▋   | 1020/1269 [00:10<00:02, 91.83it/s]
#
# Date Pairs:  81%|█████████████▊   | 1030/1269 [00:11<00:02, 92.84it/s]
#
# Date Pairs:  82%|█████████████▉   | 1040/1269 [00:11<00:02, 93.09it/s]
#
# Date Pairs:  83%|██████████████   | 1050/1269 [00:11<00:02, 93.84it/s]
#
# Date Pairs:  84%|██████████████▏  | 1060/1269 [00:11<00:02, 94.42it/s]
#
# Date Pairs:  84%|██████████████▎  | 1070/1269 [00:11<00:02, 94.60it/s]
#
# Date Pairs:  85%|██████████████▍  | 1080/1269 [00:11<00:02, 93.91it/s]
#
# Date Pairs:  86%|██████████████▌  | 1090/1269 [00:11<00:01, 93.32it/s]
#
# Date Pairs:  87%|██████████████▋  | 1100/1269 [00:11<00:01, 93.93it/s]
#
# Date Pairs:  87%|██████████████▊  | 1110/1269 [00:11<00:01, 94.07it/s]
#
# Date Pairs:  88%|███████████████  | 1120/1269 [00:11<00:01, 94.49it/s]
#
# Date Pairs:  89%|███████████████▏ | 1130/1269 [00:12<00:01, 95.29it/s]
#
# Date Pairs:  90%|███████████████▎ | 1140/1269 [00:12<00:01, 95.22it/s]
#
# Date Pairs:  91%|███████████████▍ | 1150/1269 [00:12<00:01, 94.66it/s]
#
# Date Pairs:  91%|███████████████▌ | 1160/1269 [00:12<00:01, 90.48it/s]
#
# Date Pairs:  92%|███████████████▋ | 1170/1269 [00:12<00:01, 91.87it/s]
#
# Date Pairs:  93%|███████████████▊ | 1180/1269 [00:12<00:00, 92.84it/s]
#
# Date Pairs:  94%|███████████████▉ | 1190/1269 [00:12<00:00, 93.72it/s]
#
# Date Pairs:  95%|████████████████ | 1200/1269 [00:12<00:00, 94.55it/s]
#
# Date Pairs:  95%|████████████████▏| 1210/1269 [00:12<00:00, 94.71it/s]
#
# Date Pairs:  96%|████████████████▎| 1220/1269 [00:13<00:00, 94.67it/s]
#
# Date Pairs:  97%|████████████████▍| 1230/1269 [00:13<00:00, 95.22it/s]
#
# Date Pairs:  98%|████████████████▌| 1240/1269 [00:13<00:00, 95.24it/s]
#
# Date Pairs:  99%|████████████████▋| 1250/1269 [00:13<00:00, 95.73it/s]
#
# Date Pairs: 100%|█████████████████| 1269/1269 [00:13<00:00, 93.76it/s]
#
#
# Date Pairs:   0%|                              | 0/52 [00:00<?, ?it/s]
#
# Date Pairs:  19%|████                 | 10/52 [00:00<00:00, 92.86it/s]
#
# Date Pairs:  38%|████████             | 20/52 [00:00<00:00, 93.28it/s]
#
# Date Pairs:  58%|████████████         | 30/52 [00:00<00:00, 92.63it/s]
#
# Date Pairs:  77%|████████████████▏    | 40/52 [00:00<00:00, 93.72it/s]
#
# Date Pairs: 100%|█████████████████████| 52/52 [00:00<00:00, 91.11it/s]
#
#
# Date Pairs:   0%|                              | 0/24 [00:00<?, ?it/s]
#
# Date Pairs:  42%|████████▊            | 10/24 [00:00<00:00, 94.38it/s]
#
# Date Pairs: 100%|█████████████████████| 24/24 [00:00<00:00, 92.29it/s]
#
# 100%|███████████████████████████████████| 4/4 [00:39<00:00,  9.81s/it]
# Date Pairs:   8%|█▌                 | 14/175 [00:01<00:17,  9.36it/s]
#
# Date Pairs:   9%|█▋                 | 15/175 [00:01<00:17,  9.40it/s]
#
# Date Pairs:   9%|█▋                 | 16/175 [00:01<00:16,  9.42it/s]
#
# Date Pairs:  10%|█▊                 | 17/175 [00:01<00:16,  9.39it/s]
#
# Date Pairs:  10%|█▉                 | 18/175 [00:01<00:16,  9.37it/s]
#
# Date Pairs:  11%|██                 | 19/175 [00:02<00:16,  9.36it/s]
#
# Date Pairs:  11%|██▏                | 20/175 [00:02<00:16,  9.36it/s]
#
# Date Pairs:  12%|██▎                | 21/175 [00:02<00:16,  9.36it/s]
#
# Date Pairs:  13%|██▍                | 22/175 [00:02<00:16,  9.40it/s]
#
# Date Pairs:  13%|██▍                | 23/175 [00:02<00:16,  9.40it/s]
#
# Date Pairs:  14%|██▌                | 24/175 [00:02<00:16,  9.35it/s]
#
# Date Pairs:  14%|██▋                | 25/175 [00:02<00:16,  9.33it/s]
#
# Date Pairs:  15%|██▊                | 26/175 [00:02<00:15,  9.32it/s]
#
# Date Pairs:  95%|█████████████████ | 166/175 [00:17<00:00,  9.45it/s]
#
# Date Pairs:  95%|█████████████████▏| 167/175 [00:17<00:00,  9.47it/s]
#
# Date Pairs:  96%|█████████████████▎| 168/175 [00:17<00:00,  9.45it/s]
#
# Date Pairs:  97%|█████████████████▍| 169/175 [00:18<00:00,  9.44it/s]
#
# Date Pairs:  97%|█████████████████▍| 170/175 [00:18<00:00,  9.46it/s]
#
# Date Pairs:  98%|█████████████████▌| 171/175 [00:18<00:00,  9.47it/s]
#
# Date Pairs:  98%|█████████████████▋| 172/175 [00:18<00:00,  9.47it/s]
#
# Date Pairs:  99%|█████████████████▊| 173/175 [00:18<00:00,  9.45it/s]
#
# Date Pairs:  99%|█████████████████▉| 174/175 [00:18<00:00,  9.44it/s]
#
# Date Pairs: 100%|██████████████████| 175/175 [00:18<00:00,  9.39it/s]
#
#  30%|██████████                       | 7/23 [08:46<20:51, 78.24s/it]
#
# Date Pairs: 0it [00:00, ?it/s]
#
#
# Date Pairs: 0it [00:00, ?it/s]
#
#
# Date Pairs: 0it [00:00, ?it/s]
#
#
# Date Pairs: 0it [00:00, ?it/s]
#
#
# Date Pairs: 0it [00:00, ?it/s]
#
#
# Date Pairs: 0it [00:00, ?it/s]
# /Users/cmarshak/mambaforge/envs/s1-frame-enumerator/lib/python3.11/site-packages/geopandas/io/file.py:545: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# /Users/cmarshak/mambaforge/envs/s1-frame-enumerator/lib/python3.11/site-packages/geopandas/io/file.py:545: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#
#
# Date Pairs:   0%|                            | 0/597 [00:00<?, ?it/s]
#
# Date Pairs:   0%|                    | 2/597 [00:00<00:36, 16.25it/s]
#
# Date Pairs:   1%|▏                   | 4/597 [00:00<00:36, 16.38it/s]
#
# Date Pairs:   1%|▏                   | 6/597 [00:00<00:35, 16.47it/s]
#
# Date Pairs:   1%|▎                   | 8/597 [00:00<00:35, 16.45it/s]
#
# Date Pairs:   2%|▎                  | 10/597 [00:00<00:35, 16.38it/s]
#
# Date Pairs:   2%|▍                  | 12/597 [00:00<00:35, 16.33it/s]
#
# Date Pairs:   2%|▍                  | 14/597 [00:00<00:35, 16.32it/s]
#
# Date Pairs:   3%|▌                  | 16/597 [00:00<00:35, 16.36it/s]
#
# Date Pairs:   3%|▌                  | 18/597 [00:01<00:35, 16.36it/s]
#
# Date Pairs:   3%|▋                  | 20/597 [00:01<00:35, 16.42it/s]
#
# Date Pairs:   4%|▋                  | 22/597 [00:01<00:34, 16.47it/s]
#
# Date Pairs:   4%|▊                  | 24/597 [00:01<00:34, 16.43it/s]
#
# Date Pairs:   4%|▊                  | 26/597 [00:01<00:34, 16.47it/s]
#
# Date Pairs:   5%|▉                  | 28/597 [00:01<00:34, 16.54it/s]
#
# Date Pairs:   5%|▉                  | 30/597 [00:01<00:34, 16.61it/s]
#
# Date Pairs:   5%|█                  | 32/597 [00:01<00:33, 16.63it/s]
#
# Date Pairs:   6%|█                  | 34/597 [00:02<00:33, 16.61it/s]
#
# Date Pairs:   6%|█▏                 | 36/597 [00:02<00:33, 16.66it/s]
#
# Date Pairs:   6%|█▏                 | 38/597 [00:02<00:33, 16.70it/s]
#
# Date Pairs:   7%|█▎                 | 40/597 [00:02<00:33, 16.72it/s]
#
# Date Pairs:   7%|█▎                 | 42/597 [00:02<00:33, 16.64it/s]
#
# Date Pairs:   7%|█▍                 | 44/597 [00:02<00:33, 16.65it/s]
#
# Date Pairs:   8%|█▍                 | 46/597 [00:02<00:33, 16.70it/s]
#
# Date Pairs:   8%|█▌                 | 48/597 [00:02<00:32, 16.68it/s]
#
# Date Pairs:   8%|█▌                 | 50/597 [00:03<00:32, 16.70it/s]
#
# Date Pairs:   9%|█▋                 | 52/597 [00:03<00:32, 16.70it/s]
#
# Date Pairs:   9%|█▋                 | 54/597 [00:03<00:32, 16.72it/s]
#
# Date Pairs:   9%|█▊                 | 56/597 [00:03<00:32, 16.65it/s]
#
# Date Pairs:  10%|█▊                 | 58/597 [00:03<00:32, 16.68it/s]
#
# Date Pairs:  10%|█▉                 | 60/597 [00:03<00:32, 16.69it/s]
#
# Date Pairs:  10%|█▉                 | 62/597 [00:03<00:32, 16.71it/s]
#
# Date Pairs:  11%|██                 | 64/597 [00:03<00:31, 16.71it/s]
#
# Date Pairs:  11%|██                 | 66/597 [00:03<00:31, 16.68it/s]
#
# Date Pairs:  11%|██▏                | 68/597 [00:04<00:31, 16.68it/s]
#
# Date Pairs:  12%|██▏                | 70/597 [00:04<00:31, 16.58it/s]
#
# Date Pairs:  12%|██▎                | 72/597 [00:04<00:31, 16.53it/s]
#
# Date Pairs:  12%|██▎                | 74/597 [00:04<00:31, 16.50it/s]
# Date Pairs:  13%|██▍                | 76/597 [00:04<00:31, 16.49it/s]
#
# Date Pairs:  13%|██▍                | 78/597 [00:04<00:31, 16.49it/s]
#
# Date Pairs:  13%|██▌                | 80/597 [00:04<00:31, 16.51it/s]
#
# Date Pairs:  14%|██▌                | 82/597 [00:04<00:31, 16.52it/s]
#
# Date Pairs:  14%|██▋                | 84/597 [00:05<00:31, 16.38it/s]
#
# Date Pairs:  14%|██▋                | 86/597 [00:05<00:31, 16.44it/s]
#
# Date Pairs:  15%|██▊                | 88/597 [00:05<00:30, 16.54it/s]
#
# Date Pairs:  15%|██▊                | 90/597 [00:05<00:30, 16.58it/s]
#
# Date Pairs:  15%|██▉                | 92/597 [00:05<00:30, 16.64it/s]
#
# Date Pairs:  16%|██▉                | 94/597 [00:05<00:30, 16.67it/s]
#
# Date Pairs:  16%|███                | 96/597 [00:05<00:30, 16.68it/s]
#
# Date Pairs:  16%|███                | 98/597 [00:05<00:29, 16.69it/s]
#
# Date Pairs:  17%|███               | 100/597 [00:06<00:29, 16.70it/s]
#
#
# Date Pairs:  41%|███████▍          | 246/597 [00:14<00:21, 16.54it/s]
#
# Date Pairs:  42%|███████▍          | 248/597 [00:15<00:21, 16.45it/s]
#
# Date Pairs:  42%|███████▌          | 250/597 [00:15<00:21, 16.35it/s]
#
# Date Pairs:  42%|███████▌          | 252/597 [00:15<00:21, 16.26it/s]
#
# Date Pairs:  43%|███████▋          | 254/597 [00:15<00:21, 16.30it/s]
#
# Date Pairs:  43%|███████▋          | 256/597 [00:15<00:20, 16.33it/s]
#
# ...
#
# Date Pairs:  68%|████████████▎     | 273/399 [00:09<00:04, 28.88it/s]
#
# Date Pairs:  69%|████████████▍     | 276/399 [00:09<00:04, 28.91it/s]
#
# Date Pairs:  70%|████████████▌     | 279/399 [00:09<00:04, 28.88it/s]
#
# Date Pairs:  71%|████████████▋     | 282/399 [00:09<00:04, 28.90it/s]
#
# Date Pairs:  71%|████████████▊     | 285/399 [00:09<00:03, 28.86it/s]
#
# Date Pairs:  72%|████████████▉     | 288/399 [00:10<00:03, 28.83it/s]
#
# Date Pairs:  73%|█████████████▏    | 291/399 [00:10<00:03, 28.67it/s]
#
# Date Pairs:  74%|█████████████▎    | 294/399 [00:10<00:03, 28.65it/s]
#
# Date Pairs:  74%|█████████████▍    | 297/399 [00:10<00:03, 28.57it/s]
#
# Date Pairs:  75%|█████████████▌    | 300/399 [00:10<00:03, 28.61it/s]
#
# Date Pairs:  76%|█████████████▋    | 303/399 [00:10<00:03, 28.32it/s]
#
# Date Pairs:  77%|█████████████▊    | 306/399 [00:10<00:03, 28.32it/s]
#
# Date Pairs:  77%|█████████████▉    | 309/399 [00:10<00:03, 28.32it/s]
#
# Date Pairs:  78%|██████████████    | 312/399 [00:10<00:03, 28.35it/s]
#
# Date Pairs:  79%|██████████████▏   | 315/399 [00:10<00:02, 28.35it/s]
# Date Pairs:  80%|██████████████▎   | 318/399 [00:11<00:02, 28.36it/s]
#
# Date Pairs:  80%|██████████████▍   | 321/399 [00:11<00:02, 28.17it/s]
#
# Date Pairs:  81%|██████████████▌   | 324/399 [00:11<00:02, 28.29it/s]
#
# Date Pairs:  82%|██████████████▊   | 327/399 [00:11<00:02, 28.44it/s]
#
# Date Pairs:  83%|██████████████▉   | 330/399 [00:11<00:02, 28.58it/s]
#
# Date Pairs:  83%|███████████████   | 333/399 [00:11<00:02, 28.66it/s]
#
# Date Pairs:  84%|███████████████▏  | 336/399 [00:11<00:02, 28.64it/s]
#
# Date Pairs:  85%|███████████████▎  | 339/399 [00:11<00:02, 28.53it/s]
#
# Date Pairs:  86%|███████████████▍  | 342/399 [00:11<00:01, 28.55it/s]
#
# Date Pairs:  86%|███████████████▌  | 345/399 [00:12<00:01, 28.62it/s]
#
# Date Pairs:  87%|███████████████▋  | 348/399 [00:12<00:01, 28.67it/s]
#
# Date Pairs:  88%|███████████████▊  | 351/399 [00:12<00:01, 28.60it/s]
#
# Date Pairs:  89%|███████████████▉  | 354/399 [00:12<00:01, 28.58it/s]
#
# Date Pairs:  89%|████████████████  | 357/399 [00:12<00:01, 28.51it/s]
#
# Date Pairs:  90%|████████████████▏ | 360/399 [00:12<00:01, 28.57it/s]
#
# Date Pairs:  91%|████████████████▍ | 363/399 [00:12<00:01, 28.65it/s]
#
# Date Pairs:  92%|████████████████▌ | 366/399 [00:12<00:01, 28.72it/s]
#
# Date Pairs:  92%|████████████████▋ | 369/399 [00:12<00:01, 28.61it/s]
#
# Date Pairs:  93%|████████████████▊ | 372/399 [00:12<00:00, 28.52it/s]
#
# Date Pairs:  94%|████████████████▉ | 375/399 [00:13<00:00, 28.48it/s]
#
# Date Pairs:  95%|█████████████████ | 378/399 [00:13<00:00, 28.53it/s]
#
# Date Pairs:  95%|█████████████████▏| 381/399 [00:13<00:00, 28.62it/s]
#
# Date Pairs:  96%|█████████████████▎| 384/399 [00:13<00:00, 28.72it/s]
#
# Date Pairs:  97%|█████████████████▍| 387/399 [00:13<00:00, 28.76it/s]
#
# Date Pairs:  98%|█████████████████▌| 390/399 [00:13<00:00, 28.73it/s]
#
# Date Pairs:  98%|█████████████████▋| 393/399 [00:13<00:00, 28.64it/s]
#
# Date Pairs:  99%|█████████████████▊| 396/399 [00:13<00:00, 28.63it/s]
#
# Date Pairs: 100%|██████████████████| 399/399 [00:13<00:00, 28.65it/s]
#
#
# Date Pairs:   0%|                            | 0/191 [00:00<?, ?it/s]
#
# Date Pairs:   2%|▎                   | 3/191 [00:00<00:06, 28.98it/s]
#
# Date Pairs:   3%|▋                   | 6/191 [00:00<00:06, 28.90it/s]
#
# Date Pairs:   5%|▉                   | 9/191 [00:00<00:06, 28.84it/s]
#
# Date Pairs:   6%|█▏                 | 12/191 [00:00<00:06, 28.81it/s]
#
# Date Pairs:   8%|█▍                 | 15/191 [00:00<00:06, 28.67it/s]
#
# Date Pairs:   9%|█▊                 | 18/191 [00:00<00:06, 28.70it/s]
#
# Date Pairs:  11%|██                 | 21/191 [00:00<00:05, 28.75it/s]
#
# Date Pairs:  13%|██▍                | 24/191 [00:00<00:05, 28.78it/s]
#
# Date Pairs:  14%|██▋                | 27/191 [00:00<00:05, 28.78it/s]
#
# Date Pairs:  16%|██▉                | 30/191 [00:01<00:05, 28.59it/s]
#
# Date Pairs:  17%|███▎               | 33/191 [00:01<00:05, 28.57it/s]
#
# Date Pairs:  19%|███▌               | 36/191 [00:01<00:05, 28.40it/s]
#
# Date Pairs:  20%|███▉               | 39/191 [00:01<00:05, 28.37it/s]
#
# Date Pairs:  22%|████▏              | 42/191 [00:01<00:05, 28.46it/s]
#
# Date Pairs:  24%|████▍              | 45/191 [00:01<00:05, 28.61it/s]
#
# Date Pairs:  25%|████▊              | 48/191 [00:01<00:05, 28.57it/s]
#
# Date Pairs:  27%|█████              | 51/191 [00:01<00:04, 28.40it/s]
#
# Date Pairs:  28%|█████▎             | 54/191 [00:01<00:04, 28.44it/s]
#
# Date Pairs:  30%|█████▋             | 57/191 [00:01<00:04, 28.27it/s]
#
# Date Pairs:  31%|█████▉             | 60/191 [00:02<00:04, 28.32it/s]
#
# Date Pairs:  33%|██████▎            | 63/191 [00:02<00:04, 28.37it/s]
#
# Date Pairs:  35%|██████▌            | 66/191 [00:02<00:04, 28.45it/s]
#
# Date Pairs:  36%|██████▊            | 69/191 [00:02<00:04, 28.54it/s]
#
# Date Pairs:  38%|███████▏           | 72/191 [00:02<00:04, 28.61it/s]
#
# Date Pairs:  39%|███████▍           | 75/191 [00:02<00:04, 28.68it/s]
#
# Date Pairs:  41%|███████▊           | 78/191 [00:02<00:03, 28.75it/s]
#
# Date Pairs:  42%|████████           | 81/191 [00:02<00:03, 28.75it/s]
#
# Date Pairs:  44%|████████▎          | 84/191 [00:02<00:03, 28.77it/s]
#
# Date Pairs:  46%|████████▋          | 87/191 [00:03<00:03, 28.79it/s]
#
# Date Pairs:  47%|████████▉          | 90/191 [00:03<00:03, 28.82it/s]
#
# Date Pairs:  49%|█████████▎         | 93/191 [00:03<00:03, 28.80it/s]
#
# Date Pairs:  50%|█████████▌         | 96/191 [00:03<00:03, 28.79it/s]
#
# Date Pairs:  52%|█████████▊         | 99/191 [00:03<00:03, 28.77it/s]
#
# Date Pairs:  53%|█████████▌        | 102/191 [00:03<00:03, 25.75it/s]
#
# Date Pairs:  55%|█████████▉        | 105/191 [00:03<00:03, 26.50it/s]
#
# Date Pairs:  57%|██████████▏       | 108/191 [00:03<00:03, 27.07it/s]
#
# Date Pairs:  58%|██████████▍       | 111/191 [00:03<00:02, 27.58it/s]
#
# Date Pairs:  60%|██████████▋       | 114/191 [00:04<00:02, 27.82it/s]
#
# Date Pairs:  61%|███████████       | 117/191 [00:04<00:02, 27.86it/s]
#
# Date Pairs:  63%|███████████▎      | 120/191 [00:04<00:02, 28.07it/s]
#
# Date Pairs:  64%|███████████▌      | 123/191 [00:04<00:02, 28.30it/s]
#
# Date Pairs:  66%|███████████▊      | 126/191 [00:04<00:02, 28.41it/s]
#
# Date Pairs:  68%|████████████▏     | 129/191 [00:04<00:02, 28.43it/s]
#
# Date Pairs:  69%|████████████▍     | 132/191 [00:04<00:02, 28.38it/s]
#
# Date Pairs:  71%|████████████▋     | 135/191 [00:04<00:01, 28.50it/s]
#
# Date Pairs:  72%|█████████████     | 138/191 [00:04<00:01, 28.61it/s]
#
# Date Pairs:  74%|█████████████▎    | 141/191 [00:04<00:01, 28.70it/s]
#
# Date Pairs:  75%|█████████████▌    | 144/191 [00:05<00:01, 28.77it/s]
#
# Date Pairs:  77%|█████████████▊    | 147/191 [00:05<00:01, 28.68it/s]
#
# Date Pairs:  79%|██████████████▏   | 150/191 [00:05<00:01, 28.64it/s]
#
# Date Pairs:  80%|██████████████▍   | 153/191 [00:05<00:01, 28.60it/s]
#
# Date Pairs:  82%|██████████████▋   | 156/191 [00:05<00:01, 28.53it/s]
#
# Date Pairs:  83%|██████████████▉   | 159/191 [00:05<00:01, 28.49it/s]
#
# Date Pairs:  85%|███████████████▎  | 162/191 [00:05<00:01, 28.49it/s]
#
# Date Pairs:  86%|███████████████▌  | 165/191 [00:05<00:00, 28.53it/s]
#
# Date Pairs:  88%|███████████████▊  | 168/191 [00:05<00:00, 28.53it/s]
#
# Date Pairs:  90%|████████████████  | 171/191 [00:06<00:00, 28.54it/s]
#
# Date Pairs:  91%|████████████████▍ | 174/191 [00:06<00:00, 28.55it/s]
#
# Date Pairs:  93%|████████████████▋ | 177/191 [00:06<00:00, 28.63it/s]
#
# Date Pairs:  94%|████████████████▉ | 180/191 [00:06<00:00, 28.72it/s]
#
# Date Pairs:  96%|█████████████████▏| 183/191 [00:06<00:00, 28.77it/s]
#
# Date Pairs:  97%|█████████████████▌| 186/191 [00:06<00:00, 28.83it/s]
#
# Date Pairs: 100%|██████████████████| 191/191 [00:06<00:00, 28.45it/s]
#
#
# Date Pairs:   0%|                            | 0/270 [00:00<?, ?it/s]
#
# Date Pairs:   1%|▎                   | 4/270 [00:00<00:07, 34.52it/s]
#
# Date Pairs:   3%|▌                   | 8/270 [00:00<00:07, 34.24it/s]
#
# Date Pairs:   4%|▊                  | 12/270 [00:00<00:07, 34.14it/s]
#
# Date Pairs:   6%|█▏                 | 16/270 [00:00<00:07, 34.13it/s]
#
# Date Pairs:   7%|█▍                 | 20/270 [00:00<00:07, 34.06it/s]
#
# Date Pairs:   9%|█▋                 | 24/270 [00:00<00:07, 33.87it/s]
#
# Date Pairs:  10%|█▉                 | 28/270 [00:00<00:07, 33.79it/s]
#
# Date Pairs:  12%|██▎                | 32/270 [00:00<00:07, 33.83it/s]
#
# Date Pairs:  13%|██▌                | 36/270 [00:01<00:06, 33.90it/s]
#
# Date Pairs:  15%|██▊                | 40/270 [00:01<00:06, 33.98it/s]
#
# Date Pairs:  16%|███                | 44/270 [00:01<00:06, 33.94it/s]
#
# Date Pairs:  18%|███▍               | 48/270 [00:01<00:06, 33.81it/s]
#
# Date Pairs:  19%|███▋               | 52/270 [00:01<00:06, 33.90it/s]
# Date Pairs:  21%|███▉               | 56/270 [00:01<00:06, 34.08it/s]
#
# Date Pairs:  22%|████▏              | 60/270 [00:01<00:06, 34.10it/s]
#
# Date Pairs:  24%|████▌              | 64/270 [00:01<00:06, 34.23it/s]
#
# Date Pairs:  25%|████▊              | 68/270 [00:01<00:05, 34.34it/s]
#
# Date Pairs:  27%|█████              | 72/270 [00:02<00:05, 34.31it/s]
#
# Date Pairs:  28%|█████▎             | 76/270 [00:02<00:05, 34.38it/s]
#
# Date Pairs:  30%|█████▋             | 80/270 [00:02<00:05, 34.35it/s]
#
# Date Pairs:  31%|█████▉             | 84/270 [00:02<00:05, 34.46it/s]
#
# Date Pairs:  33%|██████▏            | 88/270 [00:02<00:05, 34.50it/s]
#
# Date Pairs:  34%|██████▍            | 92/270 [00:02<00:05, 34.56it/s]
#
# Date Pairs:  36%|██████▊            | 96/270 [00:02<00:05, 34.51it/s]
#
# Date Pairs:  37%|██████▋           | 100/270 [00:02<00:04, 34.52it/s]
#
# Date Pairs:  39%|██████▉           | 104/270 [00:03<00:04, 34.40it/s]
#
# Date Pairs:  40%|███████▏          | 108/270 [00:03<00:04, 34.40it/s]
#
# Date Pairs:  41%|███████▍          | 112/270 [00:03<00:04, 34.32it/s]
#
# Date Pairs:  43%|███████▋          | 116/270 [00:03<00:04, 34.32it/s]
#
# Date Pairs:  44%|████████          | 120/270 [00:03<00:04, 34.32it/s]
#
# Date Pairs:  46%|████████▎         | 124/270 [00:03<00:04, 34.23it/s]
#
# Date Pairs:  47%|████████▌         | 128/270 [00:03<00:04, 34.28it/s]
#
# Date Pairs:  49%|████████▊         | 132/270 [00:03<00:04, 34.13it/s]
#
# Date Pairs:  50%|█████████         | 136/270 [00:03<00:03, 34.31it/s]
#
# Date Pairs:  52%|█████████▎        | 140/270 [00:04<00:03, 34.28it/s]
#
# Date Pairs:  53%|█████████▌        | 144/270 [00:04<00:03, 34.29it/s]
#
# Date Pairs:  55%|█████████▊        | 148/270 [00:04<00:03, 34.36it/s]
#
# Date Pairs:  56%|██████████▏       | 152/270 [00:04<00:03, 34.40it/s]
#
# Date Pairs:  58%|██████████▍       | 156/270 [00:04<00:03, 34.45it/s]
#
# Date Pairs:  59%|██████████▋       | 160/270 [00:04<00:03, 34.38it/s]
#
# Date Pairs:  61%|██████████▉       | 164/270 [00:04<00:03, 34.41it/s]
#
# Date Pairs:  62%|███████████▏      | 168/270 [00:04<00:02, 34.46it/s]
#
# Date Pairs:  64%|███████████▍      | 172/270 [00:05<00:02, 34.37it/s]
#
# Date Pairs:  65%|███████████▋      | 176/270 [00:05<00:02, 34.38it/s]
#
# Date Pairs:  67%|████████████      | 180/270 [00:05<00:02, 34.42it/s]
#
# Date Pairs:  68%|████████████▎     | 184/270 [00:05<00:02, 34.45it/s]
#
# Date Pairs:  70%|████████████▌     | 188/270 [00:05<00:02, 34.49it/s]
#
# Date Pairs:  71%|████████████▊     | 192/270 [00:05<00:02, 34.42it/s]
#
# Date Pairs:  73%|█████████████     | 196/270 [00:05<00:02, 34.28it/s]
#
# Date Pairs:  74%|█████████████▎    | 200/270 [00:05<00:02, 33.25it/s]
#
# Date Pairs:  76%|█████████████▌    | 204/270 [00:05<00:01, 33.47it/s]
#
# Date Pairs:  77%|█████████████▊    | 208/270 [00:06<00:01, 33.66it/s]
#
# Date Pairs:  79%|██████████████▏   | 212/270 [00:06<00:01, 33.95it/s]
#
# Date Pairs:  80%|██████████████▍   | 216/270 [00:06<00:01, 34.04it/s]
#
# Date Pairs:  81%|██████████████▋   | 220/270 [00:06<00:01, 34.12it/s]
#
# Date Pairs:  83%|██████████████▉   | 224/270 [00:06<00:01, 34.09it/s]
#
# Date Pairs:  84%|███████████████▏  | 228/270 [00:06<00:01, 34.03it/s]
#
# Date Pairs:  86%|███████████████▍  | 232/270 [00:06<00:01, 34.04it/s]
#
# Date Pairs:  87%|███████████████▋  | 236/270 [00:06<00:01, 34.00it/s]
#
# Date Pairs:  89%|████████████████  | 240/270 [00:07<00:00, 34.03it/s]
#
# Date Pairs:  90%|████████████████▎ | 244/270 [00:07<00:00, 34.21it/s]
#
# Date Pairs:  92%|████████████████▌ | 248/270 [00:07<00:00, 34.17it/s]
#
# Date Pairs:  93%|████████████████▊ | 252/270 [00:07<00:00, 34.13it/s]
#
# Date Pairs:  95%|█████████████████ | 256/270 [00:07<00:00, 33.93it/s]
#
# Date Pairs:  96%|█████████████████▎| 260/270 [00:07<00:00, 33.82it/s]
#
# Date Pairs:  98%|█████████████████▌| 264/270 [00:07<00:00, 33.84it/s]
#
# Date Pairs: 100%|██████████████████| 270/270 [00:07<00:00, 34.16it/s]
#
#
# Date Pairs:   0%|                             | 0/60 [00:00<?, ?it/s]
#
# Date Pairs:   7%|█▍                   | 4/60 [00:00<00:01, 34.63it/s]
#
# Date Pairs:  13%|██▊                  | 8/60 [00:00<00:01, 34.43it/s]
#
# Date Pairs:  20%|████                | 12/60 [00:00<00:01, 34.30it/s]
#
# Date Pairs:  27%|█████▎              | 16/60 [00:00<00:01, 34.17it/s]
#
# Date Pairs:  33%|██████▋             | 20/60 [00:00<00:01, 34.27it/s]
#
# Date Pairs:  40%|████████            | 24/60 [00:00<00:01, 34.33it/s]
#
# Date Pairs:  47%|█████████▎          | 28/60 [00:00<00:00, 34.31it/s]
#
# Date Pairs:  53%|██████████▋         | 32/60 [00:00<00:00, 34.30it/s]
#
# Date Pairs:  60%|████████████        | 36/60 [00:01<00:00, 34.42it/s]
#
# Date Pairs:  67%|█████████████▎      | 40/60 [00:01<00:00, 34.48it/s]
#
# Date Pairs:  73%|██████████████▋     | 44/60 [00:01<00:00, 34.51it/s]
#
# Date Pairs:  80%|████████████████    | 48/60 [00:01<00:00, 34.35it/s]
#
# Date Pairs:  87%|█████████████████▎  | 52/60 [00:01<00:00, 34.38it/s]
#
# Date Pairs:  93%|██████████████████▋ | 56/60 [00:01<00:00, 34.44it/s]
#
# Date Pairs: 100%|████████████████████| 60/60 [00:01<00:00, 34.39it/s]
#
#
# Date Pairs:   0%|                            | 0/129 [00:00<?, ?it/s]
#
# Date Pairs:   3%|▌                   | 4/129 [00:00<00:03, 33.92it/s]
#
# Date Pairs:   6%|█▏                  | 8/129 [00:00<00:03, 33.80it/s]
#
# Date Pairs:   9%|█▊                 | 12/129 [00:00<00:03, 33.94it/s]
#
# Date Pairs:  12%|██▎                | 16/129 [00:00<00:03, 34.11it/s]
#
# Date Pairs:  16%|██▉                | 20/129 [00:00<00:03, 34.29it/s]
#
# Date Pairs:  19%|███▌               | 24/129 [00:00<00:03, 34.16it/s]
#
# Date Pairs:  22%|████               | 28/129 [00:00<00:02, 34.22it/s]
#
# Date Pairs:  25%|████▋              | 32/129 [00:00<00:02, 34.23it/s]
#
# Date Pairs:  28%|█████▎             | 36/129 [00:01<00:02, 34.19it/s]
#
# Date Pairs:  31%|█████▉             | 40/129 [00:01<00:02, 34.23it/s]
#
# Date Pairs:  34%|██████▍            | 44/129 [00:01<00:02, 34.36it/s]
#
# Date Pairs:  37%|███████            | 48/129 [00:01<00:02, 34.40it/s]
#
# Date Pairs:  40%|███████▋           | 52/129 [00:01<00:02, 34.49it/s]
#
# Date Pairs:  43%|████████▏          | 56/129 [00:01<00:02, 34.39it/s]
#
# Date Pairs:  47%|████████▊          | 60/129 [00:01<00:02, 34.46it/s]
#
# Date Pairs:  50%|█████████▍         | 64/129 [00:01<00:01, 34.19it/s]
#
# Date Pairs:  53%|██████████         | 68/129 [00:01<00:01, 34.08it/s]
#
# Date Pairs:  56%|██████████▌        | 72/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  59%|███████████▏       | 76/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  62%|███████████▊       | 80/129 [00:02<00:01, 33.98it/s]
#
# Date Pairs:  65%|████████████▎      | 84/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  68%|████████████▉      | 88/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  71%|█████████████▌     | 92/129 [00:02<00:01, 33.88it/s]
#
# Date Pairs:  74%|██████████████▏    | 96/129 [00:02<00:00, 34.03it/s]
#
# Date Pairs:  78%|█████████████▉    | 100/129 [00:02<00:00, 34.20it/s]
#
# Date Pairs:  81%|██████████████▌   | 104/129 [00:03<00:00, 34.20it/s]
#
# Date Pairs:  84%|███████████████   | 108/129 [00:03<00:00, 34.30it/s]
#
# Date Pairs:  87%|███████████████▋  | 112/129 [00:03<00:00, 34.39it/s]
#
# Date Pairs:  90%|████████████████▏ | 116/129 [00:03<00:00, 34.46it/s]
#
# Date Pairs:  93%|████████████████▋ | 120/129 [00:03<00:00, 34.53it/s]
#
# Date Pairs:  96%|█████████████████▎| 124/129 [00:03<00:00, 34.48it/s]
#
# Date Pairs: 100%|██████████████████| 129/129 [00:03<00:00, 34.23it/s]
#
# 100%|████████████████████████████████| 23/23 [22:21<00:00, 58.35s/it]

# %% [markdown]
# # Preliminary Checks
#
# ## Visualize Spatial Coverage

# %%
dfs = [gpd.read_file(p) for p in tqdm(list(PARAMS.enum_dir.glob('*.geojson')))]

df_ifgs = pd.concat(dfs, axis=0)
# Out:
#   0%|                                           | 0/4 [00:00<?, ?it/s]
#  25%|████████▊                          | 1/4 [00:00<00:00,  7.22it/s]
# 100%|███████████████████████████████████| 4/4 [00:00<00:00, 13.00it/s]

# %%
# df_ifgs.plot(alpha=.01)

# %% [markdown]
# ## Total IFGs

# %%
df_ifgs.groupby('track_aoi_key')['reference'].count()
# Out:
# track_aoi_key
# track143     1345
# track34       705
# track34_1    1572
# Name: reference, dtype: int64

# %%
df_ifgs.shape
# Out:
# (3622, 8)

# %% [markdown]
# ## Distribution of Temporal Baselines

# %%
xx = (df_ifgs.reference_date).map(pd.Timestamp) - (df_ifgs.secondary_date).map(pd.Timestamp)

# %%
yy = xx.dt.total_seconds() / (60 * 60 * 24)

# %%
plt.hist(yy)
plt.xlabel('Temporal Baseline (days)')
# Out:
# Text(0.5, 0, 'Temporal Baseline (days)')
