# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# This notebook takes an AOI from the directory `AOIs` and prepares SLC pairing (aka "enumeration") for submission to the Hyp3-ISCE2 API.
#
# There are two general steps:
#
# 1. Create a stack of SLCs from the associated frames covering an AOI.
# 2. Pair the SLCs (enumeration) for preparation to submit to the Hyp3 API (the actual submission is in the next notebook)
#
# For each steps, we serialize the data. Note, the first step can be used for multiple enumeration strategies. There is an important aspect to the "stack" generation above. A stack here represents *all* the available SLCs for a set of *connected* frames. Part of the work done in this notebook is to obtain collections of frames that are connected. If the frames are not connected, it is too difficult to generate. We use "AOI" to describe the initial area of interest e.g. "US CONUS" or "East Coast". We will also use the term "track-AOI" which here breaks up frames based on their connectivity. If a track is concave and there is a break in acquisition track/path, then we have to separate our enumeration along each connected component.

# %%
from s1_frame_enumerator import (get_s1_stack, 
                                 filter_s1_stack_by_geometric_coverage_per_pass, 
                                 get_global_s1_frames, 
                                 get_overlapping_s1_frames, 
                                 enumerate_dates, 
                                 frames2gdf, 
                                 enumerate_gunw_time_series,
                                 gdf2frames)
from shapely.geometry import Point
import geopandas as gpd
from rasterio.crs import CRS
import numpy as np
import matplotlib.pyplot as plt
import warnings
import json
import pandas as pd
import datetime
from tqdm import tqdm
from pathlib import Path
from itertools import starmap
import yaml
from data_model import enumParams

# %% [markdown]
# # Checklist
#
# Before you begin you should have:
#
# - [ ] An AOI as a geojson in `AOIs`. Requires the name to be specified as `<AOI_NAME>.geojson`.
# - [ ] A yaml for the enumeration parameteters. It will be serialized indefinitely in `enum_configs`.
#
# # Paramaters
#
# We also have `RECOMPUTE_STACKS` as acquiring the SLC metadata takes time.

# %%
YAML_FILE = 'enumeration_parameters.yml'
RECOMPUTE_STACKS = False

# %% [markdown]
# # Load Parameters

# %%
PARAMS = enumParams.from_yaml(YAML_FILE)
PARAMS.__dict__
# Out:
# {'temporal_baseline_days': [0, 180, 365],
#  'n_secondaries_per_reference': 3,
#  'aoi_name': 'conus_west_coast',
#  'n_seeds': 3,
#  'track_numbers': None,
#  'data_directory': PosixPath('out'),
#  'date_of_enum': datetime.date(2024, 3, 13),
#  'stack_dir': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3/stack'),
#  'enum_dir': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3/enum'),
#  'yaml_path': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3/enum_params_2024-03-13.yml'),
#  'weather_model': None,
#  'month_constraint': None,
#  'exclusive_month_constraints': False,
#  'aoi_geojson_path': PosixPath('AOIs/conus_west_coast.geojson'),
#  'valid_date_ranges': None,
#  'enum_parent_dir': PosixPath('out/conus_west_coast__tb_0-180-365__neigh_3'),
#  'yaml_path_record': PosixPath('enum_configs/conus_west_coast_2024-03.yml')}

# %% [markdown]
# This serializes the data to `enum_configs` so that previous parameters can be tracked. Can also directly read an old file and simply remove this serialization.

# %%
yaml_record = PARAMS.to_yaml()
yaml_record
# Out:
# PosixPath('enum_configs/conus_west_coast_2024-03.yml')

# %% [markdown]
# # Load AOI

# %%
df_aoi = gpd.read_file(PARAMS.aoi_geojson_path)
# This ensures we only get the mainland part
df_aoi.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Get Frames overlapping AOI
#
# This first cell gets the spatially fixed frames overlapping the AOI and possibly the provided track numbers.

# %%
aoi_geo = df_aoi.geometry.unary_union
frames = get_overlapping_s1_frames(aoi_geo, track_numbers=PARAMS.track_numbers)
df_frames_all = frames2gdf(frames)
df_frames_all.head()
# Out:
#    frame_id hemisphere  track_number_min  track_number_max  \
# 0      1923       west                13                13
# 1      1924       west                13                13
# 2      1925       west                13                13
# 3      1926       west                13                13
# 4      1927       west                13                13
#
#                                             geometry
# 0  POLYGON Z ((-124.23953 48.85656 0.00000, -124....
# 1  POLYGON Z ((-124.50349 47.69977 0.00000, -124....
# 2  POLYGON Z ((-124.76600 46.54287 0.00000, -124....
# 3  POLYGON Z ((-125.02271 45.38540 0.00000, -124....
# 4  POLYGON Z ((-125.27406 44.22736 0.00000, -125....

# %% [markdown]
# Let's remove frames that have less than 25% overlap with our AOI. This ensures ISCE2 will have roughly enough area to process.

# %%
intersection_geo = df_frames_all.geometry.intersection(aoi_geo)
with warnings.catch_warnings():
    # yes, we are computing areas in lat/lon - that's ok at these latitudes
    warnings.simplefilter("ignore", category=UserWarning)
    percent_overlap = intersection_geo.area / df_frames_all.geometry.area
df_frames = df_frames_all[percent_overlap >= .2].reset_index(drop=True)
df_frames = df_frames.explode(index_parts=True)
frames = gdf2frames(df_frames)

# %%
fig, ax = plt.subplots()
df_aoi.geometry.boundary.plot(ax=ax)
df_frames_by_track = df_frames.dissolve(by='track_number_min').reset_index(drop=False)
df_frames_by_track.plot(ax=ax, 
                        column='track_number_min',
                        categorical=True,
                        alpha=.25, 
                        #legend=True
                       )
xmin, ymin, xmax, ymax = df_frames_by_track.total_bounds
ax.set_xlim(xmin - 1, xmax + 1)
ax.set_ylim(ymin - 1, ymax + 1)
# Out:
# (31.000686581066127, 50.61472809039068)

# %% [markdown]
# # Get Stack from Frame
#
# Here a "stack" refers to obtaining all the SLC's that cover spatially fixed frames on a given track (you can only do InSAR with a fixed SAR geometry! i.e. on a fixed track). See [frame-enumerator](https://github.com/ACCESS-Cloud-Based-InSAR/s1-frame-enumerator) repository for more details about our terminology related to stacks, frames and enumeration of interferometric pairs.
#
# We will serialize each stack to a geojson. If `RECOMPUTE_STACKS` is `True`, then will overwrite existing stacks to retreive the most-up-to-date stack. Our generation of a stack relies on simply hitting the ASF API through its python [library](https://github.com/asfadmin/Discovery-asf_search).
#
# Creating a workflow that "updates" an existing serialized stack is beyond the scope of this notebook, and quite frankly, not recommended, as such would require lots of book-keeping that would significantly bloat this notebook and the enumeration code. Acquiring multiple stacks covering a US coast generated in less than 30 minutes seems reasonable. Also, since the serialization of each stack is done, the stack data can be reused without re-running it.

# %%
all_tracks = df_frames.track_number_min.unique().tolist()
all_tracks[:3]
# Out:
# [13, 35, 42]

# %% [markdown]
# An important book-keeping piece is that we are going to group the frames by track *and* by its connected component into what we will also call a "track-AOIs". These "track-AOIs" are essential for enumeration (*we cannot enumerate over disconnected areas*, see the [`s1-frame-enumerator`](https://github.com/ACCESS-Cloud-Based-InSAR/s1_frame_enumerator)).
#
# The groups also are how we group jobs for accounting. A "track-AOI" is simply a contiguous set of frames that overlap our AOI. Note that a single track can become disconnected based on our AOI (this is caused by concavity in an AOI or when the AOI is itself disconnected as in the case of multiple islands). We will name these track AOIs using the convention `track{N}` where `N` is the track number for the first connected component and `track{N}-_{index}`. For example, if we have track 23 with multiple connected components, this would look like `track23, track23_1, ...`.
#
# **Warning**: We have the initial "AOI" which refers to a general area of interest for a science use case such as "US CONUS" or "Tibet" and now we *also* are grouping frames into "track-AOIs" to ensure that our enumeration is over a connected set of frames.
#
# Below we create dictionary with key `track_AOI_ID` and value a list of frames within that area. A frame is simply a data container

# %%
def id_formatter(row: pd.Series):
    """Returns 'track<track_number>' for first instance and then 'track<track_number>_k' for each subsequent k index"""
    if row['level_1']:
        return f"track{row['track_number_min']}_{row['level_1']}"
    else:
        return f"track{row['track_number_min']}"

df_track_aois = df_frames_by_track.explode().reset_index(drop=False)
df_track_aois['track_aoi_id'] = df_track_aois.apply(id_formatter, axis=1)
df_track_aois.head()
# Out:
# /var/folders/0p/d5x2m4tx5kg1246bplsvyfyh0000gq/T/ipykernel_29858/2628663778.py:8: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   df_track_aois = df_frames_by_track.explode().reset_index(drop=False)
#    level_0  level_1  track_number_min  frame_id hemisphere  track_number_max  \
# 0        0        0                13      1924       west                13
# 1        1        0                35      5287       west                35
# 2        2        0                42      6441       west                42
# 3        3        0                64      9847       west                64
# 4        3        1                64      9847       west                64
#
#                                             geometry track_aoi_id
# 0  POLYGON Z ((-126.01699 40.73057 0.00000, -126....      track13
# 1  POLYGON Z ((-124.99455 42.30143 0.00000, -125....      track35
# 2  POLYGON Z ((-122.71927 36.73546 0.00000, -122....      track42
# 3  POLYGON Z ((-121.36586 44.15190 0.00000, -121....      track64
# 4  POLYGON Z ((-118.70904 33.37855 0.00000, -118....    track64_1

# %%
track2frames = {row['track_aoi_id']: [f for f in frames 
                                      if row['track_number_min'] in f.track_numbers 
                                      if row['geometry'].intersects(f.frame_geometry)
                       ] 
                for _, row in df_track_aois.iterrows()}

keys = list(track2frames.keys())
track2frames[keys[0]]
# Out:
# [S1Frame(frame_id=1924, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-124.503 47.7 0, -124.469 47.865 0, -124.244 48.839 0, -120.754...>, footprint_geometry=<POLYGON ((-122.323 47.353, -122.933 47.424, -123.475 47.485, -123.49 47.425...>),
#  S1Frame(frame_id=1925, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-124.766 46.543 0, -124.507 47.683 0, -121.099 47.683 0, -121.1...>, footprint_geometry=<POLYGON ((-122.633 46.196, -123.23 46.267, -123.76 46.327, -123.775 46.268,...>),
#  S1Frame(frame_id=1926, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-125.023 45.385 0, -124.802 46.377 0, -124.803 46.378 0, -124.7...>, footprint_geometry=<POLYGON ((-122.932 45.038, -123.517 45.109, -124.037 45.169, -124.051 45.11...>),
#  S1Frame(frame_id=1927, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-125.274 44.227 0, -125.129 44.889 0, -125.132 44.889 0, -125.0...>, footprint_geometry=<POLYGON ((-123.225 43.879, -123.799 43.95, -124.308 44.011, -124.322 43.951...>),
#  S1Frame(frame_id=1928, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-125.522 43.069 0, -125.451 43.4 0, -125.418 43.566 0, -125.278...>, footprint_geometry=<POLYGON ((-124.588 42.793, -125.558 42.903, -125.451 43.4, -125.418 43.566,...>),
#  S1Frame(frame_id=1929, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-125.767 41.91 0, -125.732 42.076 0, -125.734 42.076 0, -125.52...>, footprint_geometry=<POLYGON ((-123.793 41.56, -124.346 41.632, -124.837 41.693, -124.851 41.633...>),
#  S1Frame(frame_id=1930, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-126.013 40.751 0, -125.771 41.891 0, -122.687 41.891 0, -122.7...>, footprint_geometry=<POLYGON ((-125.112 40.474, -126.048 40.586, -125.723 42.115, -124.802 41.99...>),
#  S1Frame(frame_id=1931, hemisphere='west', track_numbers=[13], frame_geometry=<POLYGON Z ((-126.252 39.592 0, -126.045 40.585 0, -126.047 40.586 0, -126.0...>, footprint_geometry=<POLYGON ((-125.367 39.313, -126.287 39.426, -126.045 40.585, -126.048 40.58...>)]

# %% [markdown]
# For each `track_aoi_id`, we save the stack as `track{N}-{AOI_NAME}`, hopefully the multiple use of "AOIs" is clear.

# %%
track_log = tqdm(total=0, position=0, bar_format='{desc}')

def get_s1_stack_and_serialize(track_aoi_id: str, frames: list, recompute_stack=RECOMPUTE_STACKS):
    if not frames:
        warnings.warn('No frames submitted')
        return
    track_stack_path = PARAMS.stack_dir / f'{track_aoi_id}-{PARAMS.aoi_name}.geojson'
    track_log.set_description_str(f'Current track: {track_stack_path}')
    if track_stack_path.exists() and (not recompute_stack):
        return track_stack_path
    df_stack = get_s1_stack(frames, minimum_coverage_ratio_per_frame=.2, minimum_coverage_ratio_per_pass=.8)
    if df_stack.empty:
        warnings.warn(f'Empty stack - still writing for records - check {track_aoi_id} on asf_search')
    df_stack.to_file(track_stack_path, driver='GeoJSON')
    return track_stack_path

# %%
input_frame_data = list(track2frames.items())
stack_paths = list(starmap(get_s1_stack_and_serialize, tqdm(input_frame_data)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 3157.38it/s]

# %% [markdown]
# # Generate IFG Pairs
#
# The basic enumeration is we loop through all available `min_temporal_baseline`'s and `n_secondary_per_reference` provided. Note you can provide multiple of each and they are `zip`ped up.
#
# There are additional parameters too. We can perform an independent enumeration of pairs (if `MONTH_CONSTRAINTS` is non-empty or not `None`), filtering the stack based on those months provided in the enumeration parameters. This allows us to select months with likely high-coherence.
#
# It's important to note that this is *not* part of the enumeration library (yet?) as the application of enumeration is ever evolving and often requires tweaks that are beyond the scope of a given libraries function. Although the functions appear quite long, a lot of the code is meant to assist with serializaiton as the pairings need to be recorded for (a) inspection by the Hyp3 submission and (b) for later inspection should reprocessing be required.

# %%
df_stack_sample = gpd.read_file(stack_paths[0])
df_stack_sample.head()
# Out:
#                                               slc_id  \
# 0  S1A_IW_SLC__1SSV_20150603T142049_20150603T1421...
# 1  S1A_IW_SLC__1SSV_20150603T142113_20150603T1421...
# 2  S1A_IW_SLC__1SSV_20150603T142138_20150603T1422...
# 3  S1A_IW_SLC__1SSV_20150603T142203_20150603T1422...
# 4  S1A_IW_SLC__1SSV_20150603T142229_20150603T1422...
#
#                   start_time                  stop_time  \
# 0  2015-06-03T14:20:49+00:00  2015-06-03T14:21:16+00:00
# 1  2015-06-03T14:21:13+00:00  2015-06-03T14:21:40+00:00
# 2  2015-06-03T14:21:38+00:00  2015-06-03T14:22:05+00:00
# 3  2015-06-03T14:22:03+00:00  2015-06-03T14:22:31+00:00
# 4  2015-06-03T14:22:29+00:00  2015-06-03T14:22:56+00:00
#
#                                                  url  track_number  \
# 0  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            13
# 1  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            13
# 2  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            13
# 3  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            13
# 4  https://datapool.asf.alaska.edu/SLC/SA/S1A_IW_...            13
#
#   polarization  orbit beam_mode   size_gb  stack_repeat_pass_id  \
# 0           VV   6210        IW  2.445635                     0
# 1           VV   6210        IW  2.487879                     0
# 2           VV   6210        IW  2.329180                     0
# 3           VV   6210        IW  2.378782                     0
# 4           VV   6210        IW  2.286099                     0
#
#       repeat_pass_timestamp                                           geometry
# 0 2015-06-03 00:00:00+00:00  POLYGON ((-121.11031 47.59365, -120.62312 49.2...
# 1 2015-06-03 00:00:00+00:00  POLYGON ((-121.54288 46.10712, -121.07291 47.7...
# 2 2015-06-03 00:00:00+00:00  POLYGON ((-121.95335 44.61837, -121.49852 46.2...
# 3 2015-06-03 00:00:00+00:00  POLYGON ((-122.37618 43.07177, -121.91968 44.7...
# 4 2015-06-03 00:00:00+00:00  POLYGON ((-122.77263 41.58210, -122.34444 43.2...

# %%
IFG_COLUMNS = ['reference', 'secondary', 'reference_date', 'secondary_date', 'frame_id', 'geometry']
def encode_dataframe_for_serialization(df_ifg: gpd.GeoDataFrame) -> gpd.GeoDataFrame:
    df_ifg['reference_date'] = df_ifg['reference_date'].dt.date.astype(str)
    df_ifg['secondary_date'] = df_ifg['secondary_date'].dt.date.astype(str)
    
    df_ifg['reference'] = df_ifg['reference'].map(lambda l: ' '.join(l))
    df_ifg['secondary'] = df_ifg['secondary'].map(lambda l: ' '.join(l))
    
    df_ifg.crs = CRS.from_epsg(4326)
    return df_ifg  


def enumerate_one_stack(stack_path: Path,
                        temporal_baselines_days: int, 
                        neighbors: int | list[int],
                        n_init_seeds: int,
                        month_constraints: list,
                        exclusive_month_constraints: bool,
                        valid_date_ranges: list):
    neighbors_lst = neighbors if isinstance(neighbors, list) else [neighbors] * len(temporal_baselines_days)
    
    df_stack = gpd.read_file(stack_path)
    
    stack_path_stem = stack_path.stem
    track_aoi_key, aoi_name = stack_path_stem.split('-')
    
    frames = track2frames[track_aoi_key]
    enum_data_path_track_aoi = PARAMS.enum_dir / f'{track_aoi_key}-{aoi_name}.geojson'
    
    # We prepare an empty output dataframe in case any steps yeild empty frames
    df_ifg = gpd.GeoDataFrame(columns=IFG_COLUMNS)
    df_ifg.crs = CRS.from_epsg(4326)

    all_data = []
    # Only enumerate if stack non-empty
    if not df_stack.empty:
        # We will loop through constraints and month constraints if desired
        month_constraints_enumeration = [] if exclusive_month_constraints else [False]
        if month_constraints:
            month_constraints_enumeration.append(True)            
        for constraint in month_constraints_enumeration:
            df_stack_temp = df_stack.copy()
            if constraint:
                months_in_stack = pd.to_datetime(df_stack_temp.repeat_pass_timestamp).dt.month
                ind = months_in_stack.isin(month_constraints)
                df_stack_temp = df_stack_temp[ind].reset_index(drop=True)
            if valid_date_ranges is not None:
                valid_date_ranges_ts = [(pd.to_datetime(t_0), pd.to_datetime(t_1))
                                        for (t_0, t_1) in valid_date_ranges]
                inds = [((df_stack_temp.repeat_pass_timestamp >= t_0) & (df_stack_temp.repeat_pass_timestamp <= t_1)) 
                        for (t_0, t_1) in valid_date_ranges_ts]
                ind = np.logical_or.reduce(inds)
                df_stack_temp = df_stack_temp[ind].reset_index(drop=True)
            if not df_stack_temp.empty:
                for neigh, tb in zip(neighbors_lst, temporal_baselines_days):
                    data = enumerate_gunw_time_series(df_stack_temp, 
                                                      tb, 
                                                      n_secondary_scenes_per_ref=neigh,
                                                      frames=frames,
                                                      n_init_seeds=n_init_seeds,
                                                      )
                    all_data += data

    # There are situations when the stack is non-empty and we have no pairs (literally one pass - see track 55)
    if all_data:
        df_ifg = gpd.GeoDataFrame(all_data)
        df_ifg = df_ifg.drop_duplicates(subset=['reference_date', 
                                                'secondary_date', 
                                                'frame_id']).reset_index(drop=True)
        df_ifg = encode_dataframe_for_serialization(df_ifg)
        
        # Write some important parameters
        df_ifg['track_aoi_key'] = track_aoi_key
        df_ifg['aoi_name'] = aoi_name
    
    df_ifg.to_file(enum_data_path_track_aoi, driver='GeoJSON')
    return enum_data_path_track_aoi

# %%
def enumerate_one_stack_p(stack_path: Path):
    return enumerate_one_stack(stack_path,
                               temporal_baselines_days=PARAMS.temporal_baseline_days,
                               neighbors=PARAMS.n_secondaries_per_reference,
                               n_init_seeds=PARAMS.n_seeds,
                               exclusive_month_constraints=PARAMS.exclusive_month_constraints,
                               month_constraints=PARAMS.month_constraint,
                               valid_date_ranges=PARAMS.valid_date_ranges
                              )

# %%
ifg_data_paths = list(map(enumerate_one_stack_p, tqdm(stack_paths[:])))
# Out:
#   0%|                                                                             | 0/17 [00:00<?, ?it/s]
#
# Date Pairs:   0%|                                                                | 0/246 [00:00<?, ?it/s]
#
# Date Pairs:   1%|▍                                                       | 2/246 [00:00<00:14, 17.25it/s]
#
# Date Pairs:   2%|▉                                                       | 4/246 [00:00<00:14, 17.23it/s]
#
# Date Pairs:   2%|█▎                                                      | 6/246 [00:00<00:13, 17.75it/s]
#
# Date Pairs:   3%|█▊                                                      | 8/246 [00:00<00:13, 17.93it/s]
#
# Date Pairs:   4%|██▏                                                    | 10/246 [00:00<00:13, 17.95it/s]
#
# Date Pairs:   5%|██▋                                                    | 12/246 [00:00<00:13, 17.68it/s]
#
# Date Pairs:   6%|███▏                                                   | 14/246 [00:00<00:13, 17.40it/s]
#
# Date Pairs:   7%|███▌                                                   | 16/246 [00:00<00:13, 17.38it/s]
#
# Date Pairs:   7%|████                                                   | 18/246 [00:01<00:13, 17.35it/s]
#
# Date Pairs:   8%|████▍                                                  | 20/246 [00:01<00:13, 17.36it/s]
#
# Date Pairs:   9%|████▉                                                  | 22/246 [00:01<00:12, 17.34it/s]
#
# Date Pairs:  10%|█████▎                                                 | 24/246 [00:01<00:12, 17.62it/s]
#
# Date Pairs:  11%|█████▊                                                 | 26/246 [00:01<00:12, 17.79it/s]
#
# Date Pairs:  11%|██████▎                                                | 28/246 [00:01<00:12, 17.29it/s]
#
# Date Pairs:  12%|██████▋                                                | 30/246 [00:01<00:12, 17.43it/s]
#
# Date Pairs:  13%|███████▏                                               | 32/246 [00:01<00:12, 17.52it/s]
#
# Date Pairs:  14%|███████▌                                               | 34/246 [00:01<00:12, 17.61it/s]
#
# Date Pairs:  15%|████████                                               | 36/246 [00:02<00:11, 17.82it/s]
#
# Date Pairs:  15%|████████▍                                              | 38/246 [00:02<00:11, 17.78it/s]
#
# Date Pairs:  16%|████████▉                                              | 40/246 [00:02<00:11, 17.96it/s]
#
# Date Pairs:  17%|█████████▍                                             | 42/246 [00:02<00:11, 18.05it/s]
#
# Date Pairs:  18%|█████████▊                                             | 44/246 [00:02<00:11, 18.17it/s]
#
# Date Pairs:  19%|██████████▎                                            | 46/246 [00:02<00:10, 18.20it/s]
#
# Date Pairs:  20%|██████████▋                                            | 48/246 [00:02<00:10, 18.17it/s]
#
# Date Pairs:  20%|███████████▏                                           | 50/246 [00:02<00:10, 18.21it/s]
#
# Date Pairs:  21%|███████████▋                                           | 52/246 [00:02<00:10, 18.22it/s]
#
# Date Pairs:  22%|████████████                                           | 54/246 [00:03<00:10, 18.23it/s]
#
# Date Pairs:  23%|████████████▌                                          | 56/246 [00:03<00:10, 18.25it/s]
#
# Date Pairs:  24%|████████████▉                                          | 58/246 [00:03<00:10, 18.24it/s]
#
# Date Pairs:  24%|█████████████▍                                         | 60/246 [00:03<00:10, 18.07it/s]
#
# Date Pairs:  25%|█████████████▊                                         | 62/246 [00:03<00:10, 17.99it/s]
#
# Date Pairs:  26%|██████████████▎                                        | 64/246 [00:03<00:10, 17.84it/s]
#
# Date Pairs:  27%|██████████████▊                                        | 66/246 [00:03<00:09, 18.01it/s]
#
# Date Pairs:  28%|███████████████▏                                       | 68/246 [00:03<00:09, 18.10it/s]
#
# Date Pairs:  28%|███████████████▋                                       | 70/246 [00:03<00:09, 18.09it/s]
#
# Date Pairs:  29%|████████████████                                       | 72/246 [00:04<00:09, 18.16it/s]
#
# Date Pairs:  30%|████████████████▌                                      | 74/246 [00:04<00:09, 18.18it/s]
#
# Date Pairs:  31%|████████████████▉                                      | 76/246 [00:04<00:09, 18.27it/s]
#
# Date Pairs:  32%|█████████████████▍                                     | 78/246 [00:04<00:09, 18.28it/s]
#
# Date Pairs:  33%|█████████████████▉                                     | 80/246 [00:04<00:09, 18.26it/s]
#
# Date Pairs:  33%|██████████████████▎                                    | 82/246 [00:04<00:09, 18.07it/s]
#
# Date Pairs:  34%|██████████████████▊                                    | 84/246 [00:04<00:09, 18.00it/s]
#
# Date Pairs:  35%|███████████████████▏                                   | 86/246 [00:04<00:08, 18.10it/s]
#
# Date Pairs:  36%|███████████████████▋                                   | 88/246 [00:04<00:08, 18.12it/s]
#
# Date Pairs:  37%|████████████████████                                   | 90/246 [00:05<00:08, 18.17it/s]
#
# Date Pairs:  37%|████████████████████▌                                  | 92/246 [00:05<00:08, 17.98it/s]
#
# Date Pairs:  38%|█████████████████████                                  | 94/246 [00:05<00:08, 17.97it/s]
#
# Date Pairs:  39%|█████████████████████▍                                 | 96/246 [00:05<00:08, 18.01it/s]
#
# Date Pairs:  40%|█████████████████████▉                                 | 98/246 [00:05<00:08, 18.02it/s]
#
# Date Pairs:  41%|█████████████████████▉                                | 100/246 [00:05<00:08, 17.94it/s]
#
# Date Pairs:  41%|██████████████████████▍                               | 102/246 [00:05<00:08, 17.88it/s]
#
# Date Pairs:  42%|██████████████████████▊                               | 104/246 [00:05<00:07, 17.94it/s]
#
# Date Pairs:  43%|███████████████████████▎                              | 106/246 [00:05<00:07, 18.09it/s]
#
# Date Pairs:  44%|███████████████████████▋                              | 108/246 [00:06<00:07, 18.28it/s]
#
# Date Pairs:  45%|████████████████████████▏                             | 110/246 [00:06<00:07, 18.31it/s]
#
# Date Pairs:  46%|████████████████████████▌                             | 112/246 [00:06<00:07, 18.20it/s]
#
# Date Pairs:  46%|█████████████████████████                             | 114/246 [00:06<00:07, 18.12it/s]
#
# Date Pairs:  47%|█████████████████████████▍                            | 116/246 [00:06<00:07, 18.22it/s]
#
# Date Pairs:  48%|█████████████████████████▉                            | 118/246 [00:06<00:06, 18.34it/s]
#
# Date Pairs:  49%|██████████████████████████▎                           | 120/246 [00:06<00:06, 18.30it/s]
#
# Date Pairs:  50%|██████████████████████████▊                           | 122/246 [00:06<00:06, 18.33it/s]
#
# Date Pairs:  50%|███████████████████████████▏                          | 124/246 [00:06<00:06, 18.36it/s]
#
# Date Pairs:  51%|███████████████████████████▋                          | 126/246 [00:07<00:06, 18.37it/s]
#
# Date Pairs:  52%|████████████████████████████                          | 128/246 [00:07<00:06, 18.30it/s]
#
# Date Pairs:  53%|████████████████████████████▌                         | 130/246 [00:07<00:06, 18.31it/s]
#
# Date Pairs:  54%|████████████████████████████▉                         | 132/246 [00:07<00:06, 18.43it/s]
#
# Date Pairs:  54%|█████████████████████████████▍                        | 134/246 [00:07<00:06, 18.27it/s]
#
# Date Pairs:  55%|█████████████████████████████▊                        | 136/246 [00:07<00:06, 18.09it/s]
#
# Date Pairs:  56%|██████████████████████████████▎                       | 138/246 [00:07<00:06, 17.96it/s]
#
# Date Pairs:  57%|██████████████████████████████▋                       | 140/246 [00:07<00:05, 18.10it/s]
#
# Date Pairs:  58%|███████████████████████████████▏                      | 142/246 [00:07<00:05, 18.25it/s]
#
# Date Pairs:  59%|███████████████████████████████▌                      | 144/246 [00:07<00:05, 18.40it/s]
#
# Date Pairs:  59%|████████████████████████████████                      | 146/246 [00:08<00:05, 18.37it/s]
#
# Date Pairs:  60%|████████████████████████████████▍                     | 148/246 [00:08<00:05, 18.43it/s]
#
# Date Pairs:  61%|████████████████████████████████▉                     | 150/246 [00:08<00:05, 18.45it/s]
#
# Date Pairs:  62%|█████████████████████████████████▎                    | 152/246 [00:08<00:05, 18.54it/s]
#
# Date Pairs:  63%|█████████████████████████████████▊                    | 154/246 [00:08<00:04, 18.46it/s]
#
# Date Pairs:  63%|██████████████████████████████████▏                   | 156/246 [00:08<00:04, 18.30it/s]
#
# Date Pairs:  64%|██████████████████████████████████▋                   | 158/246 [00:08<00:04, 18.25it/s]
#
# Date Pairs:  65%|███████████████████████████████████                   | 160/246 [00:08<00:04, 18.19it/s]
#
# Date Pairs:  66%|███████████████████████████████████▌                  | 162/246 [00:08<00:04, 18.21it/s]
#
# Date Pairs:  67%|████████████████████████████████████                  | 164/246 [00:09<00:04, 18.10it/s]
#
# Date Pairs:  67%|████████████████████████████████████▍                 | 166/246 [00:09<00:04, 18.24it/s]
#
# Date Pairs:  68%|████████████████████████████████████▉                 | 168/246 [00:09<00:04, 18.40it/s]
#
# Date Pairs:  69%|█████████████████████████████████████▎                | 170/246 [00:09<00:04, 18.24it/s]
#
# Date Pairs:  70%|█████████████████████████████████████▊                | 172/246 [00:09<00:04, 18.15it/s]
#
# Date Pairs:  71%|██████████████████████████████████████▏               | 174/246 [00:09<00:03, 18.13it/s]
#
# Date Pairs:  72%|██████████████████████████████████████▋               | 176/246 [00:09<00:03, 18.18it/s]
#
# Date Pairs:  72%|███████████████████████████████████████               | 178/246 [00:09<00:03, 18.01it/s]
#
# Date Pairs:  73%|███████████████████████████████████████▌              | 180/246 [00:09<00:03, 18.01it/s]
#
# Date Pairs:  74%|███████████████████████████████████████▉              | 182/246 [00:10<00:03, 18.08it/s]
#
# Date Pairs:  75%|████████████████████████████████████████▍             | 184/246 [00:10<00:03, 18.21it/s]
#
# Date Pairs:  76%|████████████████████████████████████████▊             | 186/246 [00:10<00:03, 18.24it/s]
#
# Date Pairs:  76%|█████████████████████████████████████████▎            | 188/246 [00:10<00:03, 18.26it/s]
#
# Date Pairs:  77%|█████████████████████████████████████████▋            | 190/246 [00:10<00:03, 18.23it/s]
#
# Date Pairs:  78%|██████████████████████████████████████████▏           | 192/246 [00:10<00:02, 18.29it/s]
#
# Date Pairs:  79%|██████████████████████████████████████████▌           | 194/246 [00:10<00:02, 18.40it/s]
#
# Date Pairs:  80%|███████████████████████████████████████████           | 196/246 [00:10<00:02, 18.45it/s]
#
# Date Pairs:  80%|███████████████████████████████████████████▍          | 198/246 [00:10<00:02, 18.56it/s]
#
# Date Pairs:  81%|███████████████████████████████████████████▉          | 200/246 [00:11<00:02, 18.53it/s]
#
# Date Pairs:  82%|████████████████████████████████████████████▎         | 202/246 [00:11<00:02, 18.40it/s]
#
# Date Pairs:  83%|████████████████████████████████████████████▊         | 204/246 [00:11<00:02, 18.38it/s]
#
# Date Pairs:  84%|█████████████████████████████████████████████▏        | 206/246 [00:11<00:02, 18.49it/s]
#
# Date Pairs:  85%|█████████████████████████████████████████████▋        | 208/246 [00:11<00:02, 18.40it/s]
#
# Date Pairs:  85%|██████████████████████████████████████████████        | 210/246 [00:11<00:01, 18.05it/s]
#
# Date Pairs:  86%|██████████████████████████████████████████████▌       | 212/246 [00:11<00:01, 18.06it/s]
#
# Date Pairs:  87%|██████████████████████████████████████████████▉       | 214/246 [00:11<00:01, 18.15it/s]
#
# Date Pairs:  88%|███████████████████████████████████████████████▍      | 216/246 [00:11<00:01, 17.98it/s]
#
# Date Pairs:  89%|███████████████████████████████████████████████▊      | 218/246 [00:12<00:01, 17.90it/s]
#
# Date Pairs:  89%|████████████████████████████████████████████████▎     | 220/246 [00:12<00:01, 18.07it/s]
#
# Date Pairs:  90%|████████████████████████████████████████████████▋     | 222/246 [00:12<00:01, 18.24it/s]
#
# Date Pairs:  91%|█████████████████████████████████████████████████▏    | 224/246 [00:12<00:01, 18.38it/s]
#
# Date Pairs:  92%|█████████████████████████████████████████████████▌    | 226/246 [00:12<00:01, 18.38it/s]
#
# Date Pairs:  93%|██████████████████████████████████████████████████    | 228/246 [00:12<00:00, 18.41it/s]
#
# Date Pairs:  93%|██████████████████████████████████████████████████▍   | 230/246 [00:12<00:00, 18.48it/s]
#
# Date Pairs:  94%|██████████████████████████████████████████████████▉   | 232/246 [00:12<00:00, 18.54it/s]
#
# Date Pairs:  95%|███████████████████████████████████████████████████▎  | 234/246 [00:12<00:00, 18.60it/s]
#
# Date Pairs:  96%|███████████████████████████████████████████████████▊  | 236/246 [00:13<00:00, 18.59it/s]
#
# Date Pairs:  97%|████████████████████████████████████████████████████▏ | 238/246 [00:13<00:00, 18.57it/s]
#
# Date Pairs:  98%|████████████████████████████████████████████████████▋ | 240/246 [00:13<00:00, 18.49it/s]
#
# Date Pairs:  98%|█████████████████████████████████████████████████████ | 242/246 [00:13<00:00, 18.44it/s]
#
# Date Pairs:  99%|█████████████████████████████████████████████████████▌| 244/246 [00:13<00:00, 18.46it/s]
#
# Date Pairs: 100%|██████████████████████████████████████████████████████| 246/246 [00:13<00:00, 18.14it/s]
#
#
# Date Pairs:   0%|                                                                | 0/105 [00:00<?, ?it/s]
#
# Date Pairs:   2%|█                                                       | 2/105 [00:00<00:05, 17.94it/s]
#
# Date Pairs:   4%|██▏                                                     | 4/105 [00:00<00:05, 18.32it/s]
#
# Date Pairs:   6%|███▏                                                    | 6/105 [00:00<00:05, 18.23it/s]
#
# Date Pairs:   8%|████▎                                                   | 8/105 [00:00<00:05, 17.92it/s]
#
# Date Pairs:  10%|█████▏                                                 | 10/105 [00:00<00:05, 18.11it/s]
#
# Date Pairs:  11%|██████▎                                                | 12/105 [00:00<00:05, 18.25it/s]
#
# Date Pairs:  13%|███████▎                                               | 14/105 [00:00<00:04, 18.21it/s]
#
# Date Pairs:  15%|████████▍                                              | 16/105 [00:00<00:04, 18.32it/s]
#
# Date Pairs:  17%|█████████▍                                             | 18/105 [00:00<00:04, 18.42it/s]
#
# Date Pairs:  19%|██████████▍                                            | 20/105 [00:01<00:04, 18.39it/s]
#
# Date Pairs:  21%|███████████▌                                           | 22/105 [00:01<00:04, 18.45it/s]
#
# Date Pairs:  23%|████████████▌                                          | 24/105 [00:01<00:04, 18.40it/s]
#
# Date Pairs:  25%|█████████████▌                                         | 26/105 [00:01<00:04, 18.25it/s]
#
# Date Pairs:  27%|██████████████▋                                        | 28/105 [00:01<00:04, 18.20it/s]
#
# Date Pairs:  29%|███████████████▋                                       | 30/105 [00:01<00:04, 18.31it/s]
#
# Date Pairs:  30%|████████████████▊                                      | 32/105 [00:01<00:03, 18.30it/s]
#
# Date Pairs:  32%|█████████████████▊                                     | 34/105 [00:01<00:03, 18.19it/s]
#
# Date Pairs:  34%|██████████████████▊                                    | 36/105 [00:01<00:03, 17.82it/s]
#
# Date Pairs:  36%|███████████████████▉                                   | 38/105 [00:02<00:03, 17.54it/s]
#
# Date Pairs:  38%|████████████████████▉                                  | 40/105 [00:02<00:03, 17.60it/s]
#
# Date Pairs:  40%|██████████████████████                                 | 42/105 [00:02<00:03, 17.78it/s]
#
# Date Pairs:  42%|███████████████████████                                | 44/105 [00:02<00:03, 17.84it/s]
#
# Date Pairs:  44%|████████████████████████                               | 46/105 [00:02<00:03, 17.85it/s]
#
# Date Pairs:  46%|█████████████████████████▏                             | 48/105 [00:02<00:03, 17.92it/s]
#
# Date Pairs:  48%|██████████████████████████▏                            | 50/105 [00:02<00:03, 18.12it/s]
#
# Date Pairs:  50%|███████████████████████████▏                           | 52/105 [00:02<00:02, 18.05it/s]
#
# Date Pairs:  51%|████████████████████████████▎                          | 54/105 [00:02<00:02, 17.85it/s]
#
# Date Pairs:  53%|█████████████████████████████▎                         | 56/105 [00:03<00:02, 17.91it/s]
#
# Date Pairs:  55%|██████████████████████████████▍                        | 58/105 [00:03<00:02, 18.05it/s]
#
# Date Pairs:  57%|███████████████████████████████▍                       | 60/105 [00:03<00:02, 18.01it/s]
#
# Date Pairs:  59%|████████████████████████████████▍                      | 62/105 [00:03<00:02, 18.12it/s]
#
# Date Pairs:  61%|█████████████████████████████████▌                     | 64/105 [00:03<00:02, 18.09it/s]
#
# Date Pairs:  63%|██████████████████████████████████▌                    | 66/105 [00:03<00:02, 17.91it/s]
#
# Date Pairs:  65%|███████████████████████████████████▌                   | 68/105 [00:03<00:02, 17.91it/s]
#
# Date Pairs:  67%|████████████████████████████████████▋                  | 70/105 [00:03<00:01, 17.71it/s]
#
# Date Pairs:  69%|█████████████████████████████████████▋                 | 72/105 [00:03<00:01, 17.72it/s]
#
# Date Pairs:  70%|██████████████████████████████████████▊                | 74/105 [00:04<00:01, 17.79it/s]
#
# Date Pairs:  72%|███████████████████████████████████████▊               | 76/105 [00:04<00:01, 17.70it/s]
#
# Date Pairs:  74%|████████████████████████████████████████▊              | 78/105 [00:04<00:01, 17.77it/s]
#
# Date Pairs:  76%|█████████████████████████████████████████▉             | 80/105 [00:04<00:01, 17.64it/s]
#
# Date Pairs:  78%|██████████████████████████████████████████▉            | 82/105 [00:04<00:01, 17.78it/s]
#
# Date Pairs:  80%|████████████████████████████████████████████           | 84/105 [00:04<00:01, 17.87it/s]
#
# Date Pairs:  82%|█████████████████████████████████████████████          | 86/105 [00:04<00:01, 17.65it/s]
#
# Date Pairs:  84%|██████████████████████████████████████████████         | 88/105 [00:04<00:00, 17.66it/s]
#
# Date Pairs:  86%|███████████████████████████████████████████████▏       | 90/105 [00:05<00:00, 17.70it/s]
#
# Date Pairs:  88%|████████████████████████████████████████████████▏      | 92/105 [00:05<00:00, 17.79it/s]
#
# Date Pairs:  90%|█████████████████████████████████████████████████▏     | 94/105 [00:05<00:00, 17.88it/s]
#
# Date Pairs:  91%|██████████████████████████████████████████████████▎    | 96/105 [00:05<00:00, 17.92it/s]
#
# Date Pairs:  93%|███████████████████████████████████████████████████▎   | 98/105 [00:05<00:00, 17.87it/s]
#
# Date Pairs:  95%|███████████████████████████████████████████████████▍  | 100/105 [00:05<00:00, 17.88it/s]
#
# Date Pairs:  97%|████████████████████████████████████████████████████▍ | 102/105 [00:05<00:00, 17.93it/s]
#
# Date Pairs: 100%|██████████████████████████████████████████████████████| 105/105 [00:05<00:00, 17.94it/s]
#
#
# Date Pairs:   0%|                                                                 | 0/41 [00:00<?, ?it/s]
#
# Date Pairs:   5%|██▊                                                      | 2/41 [00:00<00:02, 17.66it/s]
#
# Date Pairs:  10%|█████▌                                                   | 4/41 [00:00<00:02, 17.88it/s]
#
# Date Pairs:  15%|████████▎                                                | 6/41 [00:00<00:01, 17.89it/s]
#
# Date Pairs:  20%|███████████                                              | 8/41 [00:00<00:01, 17.74it/s]
#
# Date Pairs:  24%|█████████████▋                                          | 10/41 [00:00<00:01, 17.60it/s]
#
# Date Pairs:  29%|████████████████▍                                       | 12/41 [00:00<00:01, 17.73it/s]
#
# Date Pairs:  34%|███████████████████                                     | 14/41 [00:00<00:01, 17.80it/s]
#
# Date Pairs:  39%|█████████████████████▊                                  | 16/41 [00:00<00:01, 17.52it/s]
#
# Date Pairs:  44%|████████████████████████▌                               | 18/41 [00:01<00:01, 17.68it/s]
#
# Date Pairs:  49%|███████████████████████████▎                            | 20/41 [00:01<00:01, 17.72it/s]
#
# Date Pairs:  54%|██████████████████████████████                          | 22/41 [00:01<00:01, 17.80it/s]
#
# Date Pairs:  59%|████████████████████████████████▊                       | 24/41 [00:01<00:00, 17.83it/s]
#
# Date Pairs:  63%|███████████████████████████████████▌                    | 26/41 [00:01<00:00, 17.55it/s]
#
# Date Pairs:  68%|██████████████████████████████████████▏                 | 28/41 [00:01<00:00, 17.57it/s]
#
# Date Pairs:  73%|████████████████████████████████████████▉               | 30/41 [00:01<00:00, 17.74it/s]
#
# Date Pairs:  78%|███████████████████████████████████████████▋            | 32/41 [00:01<00:00, 17.81it/s]
#
# Date Pairs:  83%|██████████████████████████████████████████████▍         | 34/41 [00:01<00:00, 17.67it/s]
#
# Date Pairs:  88%|█████████████████████████████████████████████████▏      | 36/41 [00:02<00:00, 17.79it/s]
#
# Date Pairs:  93%|███████████████████████████████████████████████████▉    | 38/41 [00:02<00:00, 17.87it/s]
#
# Date Pairs: 100%|████████████████████████████████████████████████████████| 41/41 [00:02<00:00, 17.73it/s]
#
#   6%|████                                                                 | 1/17 [00:22<05:53, 22.12s/it]
#
# Date Pairs:   0%|                                                                | 0/543 [00:00<?, ?it/s]
#
# Date Pairs:   0%|                                                        | 1/543 [00:00<00:54,  9.94it/s]
#
# Date Pairs:   0%|▏                                                       | 2/543 [00:00<00:54,  9.92it/s]
#
# Date Pairs:   1%|▎                                                       | 3/543 [00:00<00:54,  9.86it/s]
#
# Date Pairs:   1%|▍                                                       | 4/543 [00:00<00:55,  9.79it/s]
#
# Date Pairs:   1%|▌                                                       | 5/543 [00:00<00:55,  9.68it/s]
#
# Date Pairs:   1%|▌                                                       | 6/543 [00:00<00:55,  9.73it/s]
#
# Date Pairs:   1%|▋                                                       | 7/543 [00:00<00:54,  9.81it/s]
#
# Date Pairs:   1%|▊                                                       | 8/543 [00:00<00:54,  9.86it/s]
#
# Date Pairs:   2%|▉                                                       | 9/543 [00:00<00:54,  9.83it/s]
#
# Date Pairs:   2%|█                                                      | 10/543 [00:01<00:54,  9.77it/s]
#
# Date Pairs:   2%|█                                                      | 11/543 [00:01<00:54,  9.82it/s]
#
# Date Pairs:   2%|█▎                                                     | 13/543 [00:01<00:52, 10.05it/s]
#
# Date Pairs:   3%|█▌                                                     | 15/543 [00:01<00:51, 10.19it/s]
#
# Date Pairs:   3%|█▋                                                     | 17/543 [00:01<00:52, 10.10it/s]
#
# Date Pairs:   3%|█▉                                                     | 19/543 [00:01<00:51, 10.15it/s]
#
# Date Pairs:   4%|██▏                                                    | 21/543 [00:02<00:51, 10.23it/s]
#
# Date Pairs:   4%|██▎                                                    | 23/543 [00:02<00:50, 10.29it/s]
#
# Date Pairs:   5%|██▌                                                    | 25/543 [00:02<00:50, 10.36it/s]
#
# Date Pairs:   5%|██▋                                                    | 27/543 [00:02<00:49, 10.42it/s]
#
# Date Pairs:   5%|██▉                                                    | 29/543 [00:02<00:49, 10.42it/s]
#
# Date Pairs:   6%|███▏                                                   | 31/543 [00:03<00:49, 10.42it/s]
#
# Date Pairs:   6%|███▎                                                   | 33/543 [00:03<00:48, 10.44it/s]
#
# Date Pairs:   6%|███▌                                                   | 35/543 [00:03<00:49, 10.32it/s]
#
# Date Pairs:   7%|███▋                                                   | 37/543 [00:03<00:49, 10.32it/s]
#
# Date Pairs:   7%|███▉                                                   | 39/543 [00:03<00:48, 10.31it/s]
#
# Date Pairs:   8%|████▏                                                  | 41/543 [00:04<00:48, 10.34it/s]
#
# Date Pairs:   8%|████▎                                                  | 43/543 [00:04<00:48, 10.41it/s]
#
# Date Pairs:   8%|████▌                                                  | 45/543 [00:04<00:47, 10.46it/s]
#
# Date Pairs:   9%|████▊                                                  | 47/543 [00:04<00:47, 10.39it/s]
#
# Date Pairs:   9%|████▉                                                  | 49/543 [00:04<00:47, 10.39it/s]
#
# Date Pairs:   9%|█████▏                                                 | 51/543 [00:04<00:47, 10.44it/s]
#
# Date Pairs:  10%|█████▎                                                 | 53/543 [00:05<00:47, 10.39it/s]
#
# Date Pairs:  10%|█████▌                                                 | 55/543 [00:05<00:47, 10.31it/s]
#
# Date Pairs:  10%|█████▊                                                 | 57/543 [00:05<00:47, 10.30it/s]
#
# Date Pairs:  11%|█████▉                                                 | 59/543 [00:05<00:47, 10.26it/s]
#
# Date Pairs:  11%|██████▏                                                | 61/543 [00:05<00:47, 10.25it/s]
#
# Date Pairs:  12%|██████▍                                                | 63/543 [00:06<00:46, 10.26it/s]
#
# Date Pairs:  12%|██████▌                                                | 65/543 [00:06<00:46, 10.17it/s]
#
# Date Pairs:  12%|██████▊                                                | 67/543 [00:06<00:46, 10.23it/s]
#
# Date Pairs:  13%|██████▉                                                | 69/543 [00:06<00:46, 10.30it/s]
#
# Date Pairs:  13%|███████▏                                               | 71/543 [00:06<00:45, 10.32it/s]
#
# Date Pairs:  13%|███████▍                                               | 73/543 [00:07<00:45, 10.36it/s]
#
# Date Pairs:  14%|███████▌                                               | 75/543 [00:07<00:45, 10.28it/s]
#
# Date Pairs:  14%|███████▊                                               | 77/543 [00:07<00:45, 10.33it/s]
#
# Date Pairs:  15%|████████                                               | 79/543 [00:07<00:44, 10.41it/s]
#
# Date Pairs:  15%|████████▏                                              | 81/543 [00:07<00:44, 10.38it/s]
#
# Date Pairs:  15%|████████▍                                              | 83/543 [00:08<00:47,  9.70it/s]
#
# Date Pairs:  16%|████████▌                                              | 85/543 [00:08<00:46,  9.88it/s]
#
# Date Pairs:  16%|████████▊                                              | 87/543 [00:08<00:45, 10.01it/s]
#
# Date Pairs:  16%|█████████                                              | 89/543 [00:08<00:44, 10.11it/s]
#
# Date Pairs:  17%|█████████▏                                             | 91/543 [00:08<00:44, 10.19it/s]
#
# Date Pairs:  17%|█████████▍                                             | 93/543 [00:09<00:43, 10.26it/s]
#
# Date Pairs:  17%|█████████▌                                             | 95/543 [00:09<00:43, 10.23it/s]
#
# Date Pairs:  18%|█████████▊                                             | 97/543 [00:09<00:43, 10.30it/s]
#
# Date Pairs:  18%|██████████                                             | 99/543 [00:09<00:42, 10.37it/s]
#
# Date Pairs:  19%|██████████                                            | 101/543 [00:09<00:42, 10.31it/s]
#
# Date Pairs:  19%|██████████▏                                           | 103/543 [00:10<00:42, 10.31it/s]
#
# Date Pairs:  19%|██████████▍                                           | 105/543 [00:10<00:42, 10.37it/s]
#
# Date Pairs:  20%|██████████▋                                           | 107/543 [00:10<00:42, 10.34it/s]
#
# Date Pairs:  20%|██████████▊                                           | 109/543 [00:10<00:42, 10.27it/s]
#
# Date Pairs:  20%|███████████                                           | 111/543 [00:10<00:42, 10.16it/s]
#
# Date Pairs:  21%|███████████▏                                          | 113/543 [00:11<00:42, 10.19it/s]
#
# Date Pairs:  21%|███████████▍                                          | 115/543 [00:11<00:42, 10.14it/s]
#
# Date Pairs:  22%|███████████▋                                          | 117/543 [00:11<00:41, 10.15it/s]
#
# Date Pairs:  22%|███████████▊                                          | 119/543 [00:11<00:42, 10.09it/s]
#
# Date Pairs:  22%|████████████                                          | 121/543 [00:11<00:41, 10.16it/s]
#
# Date Pairs:  23%|████████████▏                                         | 123/543 [00:12<00:41, 10.20it/s]
#
# Date Pairs:  23%|████████████▍                                         | 125/543 [00:12<00:41, 10.10it/s]
#
# Date Pairs:  23%|████████████▋                                         | 127/543 [00:12<00:41, 10.14it/s]
#
# Date Pairs:  24%|████████████▊                                         | 129/543 [00:12<00:40, 10.17it/s]
#
# Date Pairs:  24%|█████████████                                         | 131/543 [00:12<00:40, 10.20it/s]
#
# Date Pairs:  24%|█████████████▏                                        | 133/543 [00:13<00:40, 10.15it/s]
#
# Date Pairs:  25%|█████████████▍                                        | 135/543 [00:13<00:39, 10.21it/s]
#
# Date Pairs:  25%|█████████████▌                                        | 137/543 [00:13<00:39, 10.23it/s]
#
# Date Pairs:  26%|█████████████▊                                        | 139/543 [00:13<00:39, 10.18it/s]
#
# Date Pairs:  26%|██████████████                                        | 141/543 [00:13<00:39, 10.10it/s]
#
# Date Pairs:  26%|██████████████▏                                       | 143/543 [00:14<00:39, 10.11it/s]
#
# Date Pairs:  27%|██████████████▍                                       | 145/543 [00:14<00:39, 10.04it/s]
#
# Date Pairs:  27%|██████████████▌                                       | 147/543 [00:14<00:39, 10.04it/s]
#
# Date Pairs:  27%|██████████████▊                                       | 149/543 [00:14<00:39, 10.00it/s]
#
# Date Pairs:  28%|██████████████▉                                       | 150/543 [00:14<00:39,  9.94it/s]
#
# Date Pairs:  28%|███████████████                                       | 151/543 [00:14<00:40,  9.74it/s]
#
# Date Pairs:  28%|███████████████                                       | 152/543 [00:14<00:40,  9.72it/s]
#
# Date Pairs:  28%|███████████████▏                                      | 153/543 [00:15<00:40,  9.75it/s]
#
# Date Pairs:  28%|███████████████▎                                      | 154/543 [00:15<00:40,  9.71it/s]
#
# Date Pairs:  29%|███████████████▍                                      | 155/543 [00:15<00:39,  9.71it/s]
#
# Date Pairs:  29%|███████████████▌                                      | 156/543 [00:15<00:39,  9.76it/s]
#
# Date Pairs:  29%|███████████████▌                                      | 157/543 [00:15<00:39,  9.75it/s]
#
# Date Pairs:  29%|███████████████▋                                      | 158/543 [00:15<00:39,  9.71it/s]
#
# Date Pairs:  29%|███████████████▊                                      | 159/543 [00:15<00:39,  9.72it/s]
#
# Date Pairs:  29%|███████████████▉                                      | 160/543 [00:15<00:39,  9.78it/s]
#
# Date Pairs:  30%|████████████████                                      | 161/543 [00:15<00:39,  9.78it/s]
#
# Date Pairs:  30%|████████████████                                      | 162/543 [00:15<00:39,  9.72it/s]
#
# Date Pairs:  30%|████████████████▏                                     | 163/543 [00:16<00:39,  9.71it/s]
#
# Date Pairs:  30%|████████████████▎                                     | 164/543 [00:16<00:39,  9.70it/s]
#
# Date Pairs:  30%|████████████████▍                                     | 165/543 [00:16<00:39,  9.60it/s]
#
# Date Pairs:  31%|████████████████▌                                     | 166/543 [00:16<00:39,  9.60it/s]
#
# Date Pairs:  31%|████████████████▌                                     | 167/543 [00:16<00:39,  9.57it/s]
#
# Date Pairs:  31%|████████████████▋                                     | 168/543 [00:16<00:39,  9.52it/s]
#
# Date Pairs:  31%|████████████████▊                                     | 169/543 [00:16<00:39,  9.58it/s]
#
# Date Pairs:  31%|█████████████████                                     | 171/543 [00:16<00:37,  9.92it/s]
#
# Date Pairs:  32%|█████████████████                                     | 172/543 [00:16<00:37,  9.91it/s]
#
# Date Pairs:  32%|█████████████████▏                                    | 173/543 [00:17<00:37,  9.88it/s]
#
# Date Pairs:  32%|█████████████████▎                                    | 174/543 [00:17<00:37,  9.86it/s]
#
# Date Pairs:  32%|█████████████████▍                                    | 175/543 [00:17<00:37,  9.84it/s]
#
# Date Pairs:  32%|█████████████████▌                                    | 176/543 [00:17<00:37,  9.78it/s]
#
# Date Pairs:  33%|█████████████████▌                                    | 177/543 [00:17<00:37,  9.82it/s]
#
# Date Pairs:  33%|█████████████████▋                                    | 178/543 [00:17<00:37,  9.75it/s]
#
# Date Pairs:  33%|█████████████████▊                                    | 179/543 [00:17<00:37,  9.71it/s]
#
# Date Pairs:  33%|█████████████████▉                                    | 180/543 [00:17<00:37,  9.74it/s]
#
# Date Pairs:  33%|██████████████████                                    | 181/543 [00:17<00:37,  9.75it/s]
#
# Date Pairs:  34%|██████████████████                                    | 182/543 [00:18<00:37,  9.73it/s]
#
# Date Pairs:  34%|██████████████████▏                                   | 183/543 [00:18<00:37,  9.66it/s]
#
# Date Pairs:  34%|██████████████████▍                                   | 185/543 [00:18<00:36,  9.88it/s]
#
# Date Pairs:  34%|██████████████████▍                                   | 186/543 [00:18<00:36,  9.89it/s]
#
# Date Pairs:  34%|██████████████████▌                                   | 187/543 [00:18<00:36,  9.88it/s]
#
# Date Pairs:  35%|██████████████████▋                                   | 188/543 [00:18<00:36,  9.85it/s]
#
# Date Pairs:  35%|██████████████████▊                                   | 189/543 [00:18<00:35,  9.87it/s]
#
# Date Pairs:  35%|██████████████████▉                                   | 190/543 [00:18<00:36,  9.79it/s]
#
# Date Pairs:  35%|██████████████████▉                                   | 191/543 [00:18<00:35,  9.81it/s]
#
# Date Pairs:  35%|███████████████████                                   | 192/543 [00:19<00:35,  9.80it/s]
#
# Date Pairs:  36%|███████████████████▏                                  | 193/543 [00:19<00:35,  9.76it/s]
#
# Date Pairs:  36%|███████████████████▎                                  | 194/543 [00:19<00:35,  9.77it/s]
#
# Date Pairs:  36%|███████████████████▍                                  | 195/543 [00:19<00:35,  9.73it/s]
#
# Date Pairs:  36%|███████████████████▍                                  | 196/543 [00:19<00:35,  9.67it/s]
#
# Date Pairs:  36%|███████████████████▌                                  | 197/543 [00:19<00:35,  9.68it/s]
#
# Date Pairs:  36%|███████████████████▋                                  | 198/543 [00:19<00:35,  9.76it/s]
#
# Date Pairs:  37%|███████████████████▊                                  | 199/543 [00:19<00:35,  9.65it/s]
#
# Date Pairs:  37%|███████████████████▉                                  | 200/543 [00:19<00:35,  9.69it/s]
#
# Date Pairs:  37%|████████████████████                                  | 202/543 [00:20<00:34,  9.95it/s]
#
# Date Pairs:  37%|████████████████████▏                                 | 203/543 [00:20<00:34,  9.89it/s]
#
# Date Pairs:  38%|████████████████████▎                                 | 204/543 [00:20<00:34,  9.89it/s]
#
# Date Pairs:  38%|████████████████████▍                                 | 206/543 [00:20<00:33,  9.97it/s]
#
# Date Pairs:  38%|████████████████████▌                                 | 207/543 [00:20<00:33,  9.91it/s]
#
# Date Pairs:  38%|████████████████████▋                                 | 208/543 [00:20<00:33,  9.92it/s]
#
# Date Pairs:  38%|████████████████████▊                                 | 209/543 [00:20<00:33,  9.90it/s]
#
# Date Pairs:  39%|████████████████████▉                                 | 210/543 [00:20<00:33,  9.87it/s]
#
# Date Pairs:  39%|████████████████████▉                                 | 211/543 [00:20<00:33,  9.80it/s]
#
# Date Pairs:  39%|█████████████████████                                 | 212/543 [00:21<00:33,  9.79it/s]
#
# Date Pairs:  39%|█████████████████████▎                                | 214/543 [00:21<00:32, 10.01it/s]
#
# Date Pairs:  40%|█████████████████████▍                                | 215/543 [00:21<00:32,  9.96it/s]
#
# Date Pairs:  40%|█████████████████████▍                                | 216/543 [00:21<00:33,  9.82it/s]
#
# Date Pairs:  40%|█████████████████████▌                                | 217/543 [00:21<00:33,  9.77it/s]
#
# Date Pairs:  40%|█████████████████████▋                                | 218/543 [00:21<00:33,  9.77it/s]
#
# Date Pairs:  40%|█████████████████████▊                                | 219/543 [00:21<00:33,  9.72it/s]
#
# Date Pairs:  41%|█████████████████████▉                                | 220/543 [00:21<00:33,  9.73it/s]
#
# Date Pairs:  41%|█████████████████████▉                                | 221/543 [00:21<00:33,  9.71it/s]
#
# Date Pairs:  41%|██████████████████████                                | 222/543 [00:22<00:32,  9.78it/s]
#
# Date Pairs:  41%|██████████████████████▏                               | 223/543 [00:22<00:32,  9.77it/s]
#
# Date Pairs:  41%|██████████████████████▎                               | 224/543 [00:22<00:32,  9.71it/s]
#
# Date Pairs:  41%|██████████████████████▍                               | 225/543 [00:22<00:32,  9.71it/s]
#
# Date Pairs:  42%|██████████████████████▌                               | 227/543 [00:22<00:31,  9.89it/s]
#
# Date Pairs:  42%|██████████████████████▋                               | 228/543 [00:22<00:31,  9.86it/s]
#
# Date Pairs:  42%|██████████████████████▊                               | 229/543 [00:22<00:31,  9.85it/s]
#
# Date Pairs:  42%|██████████████████████▊                               | 230/543 [00:22<00:32,  9.78it/s]
#
# Date Pairs:  43%|██████████████████████▉                               | 231/543 [00:22<00:32,  9.68it/s]
#
# Date Pairs:  43%|███████████████████████                               | 232/543 [00:23<00:31,  9.72it/s]
#
# Date Pairs:  43%|███████████████████████▏                              | 233/543 [00:23<00:31,  9.77it/s]
#
# Date Pairs:  43%|███████████████████████▎                              | 234/543 [00:23<00:31,  9.78it/s]
#
# Date Pairs:  43%|███████████████████████▎                              | 235/543 [00:23<00:31,  9.76it/s]
#
# Date Pairs:  43%|███████████████████████▍                              | 236/543 [00:23<00:31,  9.72it/s]
#
# Date Pairs:  44%|███████████████████████▌                              | 237/543 [00:23<00:31,  9.78it/s]
#
# Date Pairs:  44%|███████████████████████▊                              | 239/543 [00:23<00:30, 10.03it/s]
#
# Date Pairs:  44%|███████████████████████▊                              | 240/543 [00:23<00:30,  9.90it/s]
#
# Date Pairs:  44%|███████████████████████▉                              | 241/543 [00:24<00:30,  9.81it/s]
#
# Date Pairs:  45%|████████████████████████▏                             | 243/543 [00:24<00:29, 10.03it/s]
#
# Date Pairs:  45%|████████████████████████▎                             | 244/543 [00:24<00:30,  9.90it/s]
#
# Date Pairs:  45%|████████████████████████▎                             | 245/543 [00:24<00:30,  9.90it/s]
#
# Date Pairs:  45%|████████████████████████▍                             | 246/543 [00:24<00:30,  9.89it/s]
#
# Date Pairs:  45%|████████████████████████▌                             | 247/543 [00:24<00:30,  9.85it/s]
#
# Date Pairs:  46%|████████████████████████▋                             | 248/543 [00:24<00:30,  9.83it/s]
#
# Date Pairs:  46%|████████████████████████▊                             | 249/543 [00:24<00:29,  9.85it/s]
#
# Date Pairs:  46%|████████████████████████▉                             | 251/543 [00:25<00:28, 10.07it/s]
#
# Date Pairs:  46%|█████████████████████████                             | 252/543 [00:25<00:29,  9.98it/s]
#
# Date Pairs:  47%|█████████████████████████▏                            | 253/543 [00:25<00:29,  9.78it/s]
#
# Date Pairs:  47%|█████████████████████████▎                            | 254/543 [00:25<00:29,  9.69it/s]
#
# Date Pairs:  47%|█████████████████████████▎                            | 255/543 [00:25<00:29,  9.72it/s]
#
# Date Pairs:  47%|█████████████████████████▍                            | 256/543 [00:25<00:29,  9.71it/s]
#
# Date Pairs:  47%|█████████████████████████▌                            | 257/543 [00:25<00:29,  9.72it/s]
#
# Date Pairs:  48%|█████████████████████████▋                            | 258/543 [00:25<00:29,  9.77it/s]
#
# Date Pairs:  48%|█████████████████████████▊                            | 260/543 [00:25<00:28, 10.04it/s]
#
# Date Pairs:  48%|██████████████████████████                            | 262/543 [00:26<00:27, 10.17it/s]
#
# Date Pairs:  49%|██████████████████████████▎                           | 264/543 [00:26<00:27, 10.19it/s]
#
# Date Pairs:  49%|██████████████████████████▍                           | 266/543 [00:26<00:27, 10.15it/s]
#
# Date Pairs:  49%|██████████████████████████▋                           | 268/543 [00:26<00:26, 10.22it/s]
#
# Date Pairs:  50%|██████████████████████████▊                           | 270/543 [00:26<00:26, 10.31it/s]
#
# Date Pairs:  50%|███████████████████████████                           | 272/543 [00:27<00:26, 10.35it/s]
#
# Date Pairs:  50%|███████████████████████████▏                          | 274/543 [00:27<00:25, 10.39it/s]
#
# Date Pairs:  51%|███████████████████████████▍                          | 276/543 [00:27<00:25, 10.30it/s]
#
# Date Pairs:  51%|███████████████████████████▋                          | 278/543 [00:27<00:25, 10.30it/s]
#
# Date Pairs:  52%|███████████████████████████▊                          | 280/543 [00:27<00:25, 10.35it/s]
#
# Date Pairs:  52%|████████████████████████████                          | 282/543 [00:28<00:25, 10.40it/s]
#
# Date Pairs:  52%|████████████████████████████▏                         | 284/543 [00:28<00:24, 10.40it/s]
#
# Date Pairs:  53%|████████████████████████████▍                         | 286/543 [00:28<00:24, 10.29it/s]
#
# Date Pairs:  53%|████████████████████████████▋                         | 288/543 [00:28<00:25, 10.20it/s]
#
# Date Pairs:  53%|████████████████████████████▊                         | 290/543 [00:28<00:24, 10.20it/s]
#
# Date Pairs:  54%|█████████████████████████████                         | 292/543 [00:29<00:24, 10.11it/s]
#
# Date Pairs:  54%|█████████████████████████████▏                        | 294/543 [00:29<00:24, 10.16it/s]
#
# Date Pairs:  55%|█████████████████████████████▍                        | 296/543 [00:29<00:24, 10.10it/s]
#
# Date Pairs:  55%|█████████████████████████████▋                        | 298/543 [00:29<00:24, 10.08it/s]
#
# Date Pairs:  55%|█████████████████████████████▊                        | 300/543 [00:29<00:24, 10.03it/s]
#
# Date Pairs:  56%|██████████████████████████████                        | 302/543 [00:30<00:24,  9.99it/s]
#
# Date Pairs:  56%|██████████████████████████████▏                       | 303/543 [00:30<00:24,  9.92it/s]
#
# Date Pairs:  56%|██████████████████████████████▏                       | 304/543 [00:30<00:24,  9.89it/s]
#
# Date Pairs:  56%|██████████████████████████████▎                       | 305/543 [00:30<00:24,  9.90it/s]
#
# Date Pairs:  56%|██████████████████████████████▍                       | 306/543 [00:30<00:23,  9.88it/s]
#
# Date Pairs:  57%|██████████████████████████████▌                       | 307/543 [00:30<00:23,  9.84it/s]
#
# Date Pairs:  57%|██████████████████████████████▋                       | 308/543 [00:30<00:24,  9.79it/s]
#
# Date Pairs:  57%|██████████████████████████████▋                       | 309/543 [00:30<00:24,  9.62it/s]
#
# Date Pairs:  57%|██████████████████████████████▊                       | 310/543 [00:30<00:25,  9.30it/s]
#
# Date Pairs:  57%|██████████████████████████████▉                       | 311/543 [00:30<00:25,  9.27it/s]
#
# Date Pairs:  57%|███████████████████████████████                       | 312/543 [00:31<00:24,  9.35it/s]
#
# Date Pairs:  58%|███████████████████████████████▏                      | 313/543 [00:31<00:24,  9.41it/s]
#
# Date Pairs:  58%|███████████████████████████████▏                      | 314/543 [00:31<00:24,  9.47it/s]
#
# Date Pairs:  58%|███████████████████████████████▎                      | 315/543 [00:31<00:23,  9.59it/s]
#
# Date Pairs:  58%|███████████████████████████████▍                      | 316/543 [00:31<00:23,  9.63it/s]
#
# Date Pairs:  58%|███████████████████████████████▌                      | 317/543 [00:31<00:23,  9.66it/s]
#
# Date Pairs:  59%|███████████████████████████████▌                      | 318/543 [00:31<00:23,  9.72it/s]
#
# Date Pairs:  59%|███████████████████████████████▋                      | 319/543 [00:31<00:23,  9.65it/s]
#
# Date Pairs:  59%|███████████████████████████████▊                      | 320/543 [00:31<00:22,  9.72it/s]
#
# Date Pairs:  59%|███████████████████████████████▉                      | 321/543 [00:32<00:22,  9.74it/s]
#
# Date Pairs:  59%|████████████████████████████████                      | 322/543 [00:32<00:22,  9.71it/s]
#
# Date Pairs:  59%|████████████████████████████████                      | 323/543 [00:32<00:22,  9.78it/s]
#
# Date Pairs:  60%|████████████████████████████████▏                     | 324/543 [00:32<00:22,  9.65it/s]
#
# Date Pairs:  60%|████████████████████████████████▎                     | 325/543 [00:32<00:22,  9.54it/s]
#
# Date Pairs:  60%|████████████████████████████████▍                     | 326/543 [00:32<00:22,  9.55it/s]
#
# Date Pairs:  60%|████████████████████████████████▌                     | 327/543 [00:32<00:22,  9.52it/s]
#
# Date Pairs:  60%|████████████████████████████████▌                     | 328/543 [00:32<00:22,  9.50it/s]
#
# Date Pairs:  61%|████████████████████████████████▋                     | 329/543 [00:32<00:22,  9.59it/s]
#
# Date Pairs:  61%|████████████████████████████████▊                     | 330/543 [00:32<00:21,  9.70it/s]
#
# Date Pairs:  61%|█████████████████████████████████                     | 332/543 [00:33<00:21,  9.97it/s]
#
# Date Pairs:  61%|█████████████████████████████████                     | 333/543 [00:33<00:21,  9.90it/s]
#
# Date Pairs:  62%|█████████████████████████████████▏                    | 334/543 [00:33<00:21,  9.79it/s]
#
# Date Pairs:  62%|█████████████████████████████████▎                    | 335/543 [00:33<00:21,  9.78it/s]
#
# Date Pairs:  62%|█████████████████████████████████▍                    | 336/543 [00:33<00:21,  9.64it/s]
#
# Date Pairs:  62%|█████████████████████████████████▌                    | 337/543 [00:33<00:21,  9.69it/s]
#
# Date Pairs:  62%|█████████████████████████████████▌                    | 338/543 [00:33<00:21,  9.72it/s]
#
# Date Pairs:  62%|█████████████████████████████████▋                    | 339/543 [00:33<00:21,  9.67it/s]
#
# Date Pairs:  63%|█████████████████████████████████▊                    | 340/543 [00:33<00:21,  9.54it/s]
#
# Date Pairs:  63%|█████████████████████████████████▉                    | 341/543 [00:34<00:20,  9.65it/s]
#
# Date Pairs:  63%|██████████████████████████████████                    | 342/543 [00:34<00:20,  9.59it/s]
#
# Date Pairs:  63%|██████████████████████████████████                    | 343/543 [00:34<00:20,  9.61it/s]
#
# Date Pairs:  63%|██████████████████████████████████▏                   | 344/543 [00:34<00:20,  9.65it/s]
#
# Date Pairs:  64%|██████████████████████████████████▎                   | 345/543 [00:34<00:20,  9.71it/s]
#
# Date Pairs:  64%|██████████████████████████████████▍                   | 346/543 [00:34<00:20,  9.58it/s]
#
# Date Pairs:  64%|██████████████████████████████████▌                   | 347/543 [00:34<00:20,  9.58it/s]
#
# Date Pairs:  64%|██████████████████████████████████▌                   | 348/543 [00:34<00:20,  9.63it/s]
#
# ...
#
# Date Pairs:  68%|████████████▎     | 273/399 [00:09<00:04, 28.88it/s]
#
# Date Pairs:  69%|████████████▍     | 276/399 [00:09<00:04, 28.91it/s]
#
# Date Pairs:  70%|████████████▌     | 279/399 [00:09<00:04, 28.88it/s]
#
# Date Pairs:  71%|████████████▋     | 282/399 [00:09<00:04, 28.90it/s]
#
# Date Pairs:  71%|████████████▊     | 285/399 [00:09<00:03, 28.86it/s]
#
# Date Pairs:  72%|████████████▉     | 288/399 [00:10<00:03, 28.83it/s]
#
# Date Pairs:  73%|█████████████▏    | 291/399 [00:10<00:03, 28.67it/s]
#
# Date Pairs:  74%|█████████████▎    | 294/399 [00:10<00:03, 28.65it/s]
#
# Date Pairs:  74%|█████████████▍    | 297/399 [00:10<00:03, 28.57it/s]
#
# Date Pairs:  75%|█████████████▌    | 300/399 [00:10<00:03, 28.61it/s]
#
# Date Pairs:  76%|█████████████▋    | 303/399 [00:10<00:03, 28.32it/s]
#
# Date Pairs:  77%|█████████████▊    | 306/399 [00:10<00:03, 28.32it/s]
#
# Date Pairs:  77%|█████████████▉    | 309/399 [00:10<00:03, 28.32it/s]
#
# Date Pairs:  78%|██████████████    | 312/399 [00:10<00:03, 28.35it/s]
#
# Date Pairs:  79%|██████████████▏   | 315/399 [00:10<00:02, 28.35it/s]
# Date Pairs:  80%|██████████████▎   | 318/399 [00:11<00:02, 28.36it/s]
#
# Date Pairs:  80%|██████████████▍   | 321/399 [00:11<00:02, 28.17it/s]
#
# Date Pairs:  81%|██████████████▌   | 324/399 [00:11<00:02, 28.29it/s]
#
# Date Pairs:  82%|██████████████▊   | 327/399 [00:11<00:02, 28.44it/s]
#
# Date Pairs:  83%|██████████████▉   | 330/399 [00:11<00:02, 28.58it/s]
#
# Date Pairs:  83%|███████████████   | 333/399 [00:11<00:02, 28.66it/s]
#
# Date Pairs:  84%|███████████████▏  | 336/399 [00:11<00:02, 28.64it/s]
#
# Date Pairs:  85%|███████████████▎  | 339/399 [00:11<00:02, 28.53it/s]
#
# Date Pairs:  86%|███████████████▍  | 342/399 [00:11<00:01, 28.55it/s]
#
# Date Pairs:  86%|███████████████▌  | 345/399 [00:12<00:01, 28.62it/s]
#
# Date Pairs:  87%|███████████████▋  | 348/399 [00:12<00:01, 28.67it/s]
#
# Date Pairs:  88%|███████████████▊  | 351/399 [00:12<00:01, 28.60it/s]
#
# Date Pairs:  89%|███████████████▉  | 354/399 [00:12<00:01, 28.58it/s]
#
# Date Pairs:  89%|████████████████  | 357/399 [00:12<00:01, 28.51it/s]
#
# Date Pairs:  90%|████████████████▏ | 360/399 [00:12<00:01, 28.57it/s]
#
# Date Pairs:  91%|████████████████▍ | 363/399 [00:12<00:01, 28.65it/s]
#
# Date Pairs:  92%|████████████████▌ | 366/399 [00:12<00:01, 28.72it/s]
#
# Date Pairs:  92%|████████████████▋ | 369/399 [00:12<00:01, 28.61it/s]
#
# Date Pairs:  93%|████████████████▊ | 372/399 [00:12<00:00, 28.52it/s]
#
# Date Pairs:  94%|████████████████▉ | 375/399 [00:13<00:00, 28.48it/s]
#
# Date Pairs:  95%|█████████████████ | 378/399 [00:13<00:00, 28.53it/s]
#
# Date Pairs:  95%|█████████████████▏| 381/399 [00:13<00:00, 28.62it/s]
#
# Date Pairs:  96%|█████████████████▎| 384/399 [00:13<00:00, 28.72it/s]
#
# Date Pairs:  97%|█████████████████▍| 387/399 [00:13<00:00, 28.76it/s]
#
# Date Pairs:  98%|█████████████████▌| 390/399 [00:13<00:00, 28.73it/s]
#
# Date Pairs:  98%|█████████████████▋| 393/399 [00:13<00:00, 28.64it/s]
#
# Date Pairs:  99%|█████████████████▊| 396/399 [00:13<00:00, 28.63it/s]
#
# Date Pairs: 100%|██████████████████| 399/399 [00:13<00:00, 28.65it/s]
#
#
# Date Pairs:   0%|                            | 0/191 [00:00<?, ?it/s]
#
# Date Pairs:   2%|▎                   | 3/191 [00:00<00:06, 28.98it/s]
#
# Date Pairs:   3%|▋                   | 6/191 [00:00<00:06, 28.90it/s]
#
# Date Pairs:   5%|▉                   | 9/191 [00:00<00:06, 28.84it/s]
#
# Date Pairs:   6%|█▏                 | 12/191 [00:00<00:06, 28.81it/s]
#
# Date Pairs:   8%|█▍                 | 15/191 [00:00<00:06, 28.67it/s]
#
# Date Pairs:   9%|█▊                 | 18/191 [00:00<00:06, 28.70it/s]
#
# Date Pairs:  11%|██                 | 21/191 [00:00<00:05, 28.75it/s]
#
# Date Pairs:  13%|██▍                | 24/191 [00:00<00:05, 28.78it/s]
#
# Date Pairs:  14%|██▋                | 27/191 [00:00<00:05, 28.78it/s]
#
# Date Pairs:  16%|██▉                | 30/191 [00:01<00:05, 28.59it/s]
#
# Date Pairs:  17%|███▎               | 33/191 [00:01<00:05, 28.57it/s]
#
# Date Pairs:  19%|███▌               | 36/191 [00:01<00:05, 28.40it/s]
#
# Date Pairs:  20%|███▉               | 39/191 [00:01<00:05, 28.37it/s]
#
# Date Pairs:  22%|████▏              | 42/191 [00:01<00:05, 28.46it/s]
#
# Date Pairs:  24%|████▍              | 45/191 [00:01<00:05, 28.61it/s]
#
# Date Pairs:  25%|████▊              | 48/191 [00:01<00:05, 28.57it/s]
#
# Date Pairs:  27%|█████              | 51/191 [00:01<00:04, 28.40it/s]
#
# Date Pairs:  28%|█████▎             | 54/191 [00:01<00:04, 28.44it/s]
#
# Date Pairs:  30%|█████▋             | 57/191 [00:01<00:04, 28.27it/s]
#
# Date Pairs:  31%|█████▉             | 60/191 [00:02<00:04, 28.32it/s]
#
# Date Pairs:  33%|██████▎            | 63/191 [00:02<00:04, 28.37it/s]
#
# Date Pairs:  35%|██████▌            | 66/191 [00:02<00:04, 28.45it/s]
#
# Date Pairs:  36%|██████▊            | 69/191 [00:02<00:04, 28.54it/s]
#
# Date Pairs:  38%|███████▏           | 72/191 [00:02<00:04, 28.61it/s]
#
# Date Pairs:  39%|███████▍           | 75/191 [00:02<00:04, 28.68it/s]
#
# Date Pairs:  41%|███████▊           | 78/191 [00:02<00:03, 28.75it/s]
#
# Date Pairs:  42%|████████           | 81/191 [00:02<00:03, 28.75it/s]
#
# Date Pairs:  44%|████████▎          | 84/191 [00:02<00:03, 28.77it/s]
#
# Date Pairs:  46%|████████▋          | 87/191 [00:03<00:03, 28.79it/s]
#
# Date Pairs:  47%|████████▉          | 90/191 [00:03<00:03, 28.82it/s]
#
# Date Pairs:  49%|█████████▎         | 93/191 [00:03<00:03, 28.80it/s]
#
# Date Pairs:  50%|█████████▌         | 96/191 [00:03<00:03, 28.79it/s]
#
# Date Pairs:  52%|█████████▊         | 99/191 [00:03<00:03, 28.77it/s]
#
# Date Pairs:  53%|█████████▌        | 102/191 [00:03<00:03, 25.75it/s]
#
# Date Pairs:  55%|█████████▉        | 105/191 [00:03<00:03, 26.50it/s]
#
# Date Pairs:  57%|██████████▏       | 108/191 [00:03<00:03, 27.07it/s]
#
# Date Pairs:  58%|██████████▍       | 111/191 [00:03<00:02, 27.58it/s]
#
# Date Pairs:  60%|██████████▋       | 114/191 [00:04<00:02, 27.82it/s]
#
# Date Pairs:  61%|███████████       | 117/191 [00:04<00:02, 27.86it/s]
#
# Date Pairs:  63%|███████████▎      | 120/191 [00:04<00:02, 28.07it/s]
#
# Date Pairs:  64%|███████████▌      | 123/191 [00:04<00:02, 28.30it/s]
#
# Date Pairs:  66%|███████████▊      | 126/191 [00:04<00:02, 28.41it/s]
#
# Date Pairs:  68%|████████████▏     | 129/191 [00:04<00:02, 28.43it/s]
#
# Date Pairs:  69%|████████████▍     | 132/191 [00:04<00:02, 28.38it/s]
#
# Date Pairs:  71%|████████████▋     | 135/191 [00:04<00:01, 28.50it/s]
#
# Date Pairs:  72%|█████████████     | 138/191 [00:04<00:01, 28.61it/s]
#
# Date Pairs:  74%|█████████████▎    | 141/191 [00:04<00:01, 28.70it/s]
#
# Date Pairs:  75%|█████████████▌    | 144/191 [00:05<00:01, 28.77it/s]
#
# Date Pairs:  77%|█████████████▊    | 147/191 [00:05<00:01, 28.68it/s]
#
# Date Pairs:  79%|██████████████▏   | 150/191 [00:05<00:01, 28.64it/s]
#
# Date Pairs:  80%|██████████████▍   | 153/191 [00:05<00:01, 28.60it/s]
#
# Date Pairs:  82%|██████████████▋   | 156/191 [00:05<00:01, 28.53it/s]
#
# Date Pairs:  83%|██████████████▉   | 159/191 [00:05<00:01, 28.49it/s]
#
# Date Pairs:  85%|███████████████▎  | 162/191 [00:05<00:01, 28.49it/s]
#
# Date Pairs:  86%|███████████████▌  | 165/191 [00:05<00:00, 28.53it/s]
#
# Date Pairs:  88%|███████████████▊  | 168/191 [00:05<00:00, 28.53it/s]
#
# Date Pairs:  90%|████████████████  | 171/191 [00:06<00:00, 28.54it/s]
#
# Date Pairs:  91%|████████████████▍ | 174/191 [00:06<00:00, 28.55it/s]
#
# Date Pairs:  93%|████████████████▋ | 177/191 [00:06<00:00, 28.63it/s]
#
# Date Pairs:  94%|████████████████▉ | 180/191 [00:06<00:00, 28.72it/s]
#
# Date Pairs:  96%|█████████████████▏| 183/191 [00:06<00:00, 28.77it/s]
#
# Date Pairs:  97%|█████████████████▌| 186/191 [00:06<00:00, 28.83it/s]
#
# Date Pairs: 100%|██████████████████| 191/191 [00:06<00:00, 28.45it/s]
#
#
# Date Pairs:   0%|                            | 0/270 [00:00<?, ?it/s]
#
# Date Pairs:   1%|▎                   | 4/270 [00:00<00:07, 34.52it/s]
#
# Date Pairs:   3%|▌                   | 8/270 [00:00<00:07, 34.24it/s]
#
# Date Pairs:   4%|▊                  | 12/270 [00:00<00:07, 34.14it/s]
#
# Date Pairs:   6%|█▏                 | 16/270 [00:00<00:07, 34.13it/s]
#
# Date Pairs:   7%|█▍                 | 20/270 [00:00<00:07, 34.06it/s]
#
# Date Pairs:   9%|█▋                 | 24/270 [00:00<00:07, 33.87it/s]
#
# Date Pairs:  10%|█▉                 | 28/270 [00:00<00:07, 33.79it/s]
#
# Date Pairs:  12%|██▎                | 32/270 [00:00<00:07, 33.83it/s]
#
# Date Pairs:  13%|██▌                | 36/270 [00:01<00:06, 33.90it/s]
#
# Date Pairs:  15%|██▊                | 40/270 [00:01<00:06, 33.98it/s]
#
# Date Pairs:  16%|███                | 44/270 [00:01<00:06, 33.94it/s]
#
# Date Pairs:  18%|███▍               | 48/270 [00:01<00:06, 33.81it/s]
#
# Date Pairs:  19%|███▋               | 52/270 [00:01<00:06, 33.90it/s]
# Date Pairs:  21%|███▉               | 56/270 [00:01<00:06, 34.08it/s]
#
# Date Pairs:  22%|████▏              | 60/270 [00:01<00:06, 34.10it/s]
#
# Date Pairs:  24%|████▌              | 64/270 [00:01<00:06, 34.23it/s]
#
# Date Pairs:  25%|████▊              | 68/270 [00:01<00:05, 34.34it/s]
#
# Date Pairs:  27%|█████              | 72/270 [00:02<00:05, 34.31it/s]
#
# Date Pairs:  28%|█████▎             | 76/270 [00:02<00:05, 34.38it/s]
#
# Date Pairs:  30%|█████▋             | 80/270 [00:02<00:05, 34.35it/s]
#
# Date Pairs:  31%|█████▉             | 84/270 [00:02<00:05, 34.46it/s]
#
# Date Pairs:  33%|██████▏            | 88/270 [00:02<00:05, 34.50it/s]
#
# Date Pairs:  34%|██████▍            | 92/270 [00:02<00:05, 34.56it/s]
#
# Date Pairs:  36%|██████▊            | 96/270 [00:02<00:05, 34.51it/s]
#
# Date Pairs:  37%|██████▋           | 100/270 [00:02<00:04, 34.52it/s]
#
# Date Pairs:  39%|██████▉           | 104/270 [00:03<00:04, 34.40it/s]
#
# Date Pairs:  40%|███████▏          | 108/270 [00:03<00:04, 34.40it/s]
#
# Date Pairs:  41%|███████▍          | 112/270 [00:03<00:04, 34.32it/s]
#
# Date Pairs:  43%|███████▋          | 116/270 [00:03<00:04, 34.32it/s]
#
# Date Pairs:  44%|████████          | 120/270 [00:03<00:04, 34.32it/s]
#
# Date Pairs:  46%|████████▎         | 124/270 [00:03<00:04, 34.23it/s]
#
# Date Pairs:  47%|████████▌         | 128/270 [00:03<00:04, 34.28it/s]
#
# Date Pairs:  49%|████████▊         | 132/270 [00:03<00:04, 34.13it/s]
#
# Date Pairs:  50%|█████████         | 136/270 [00:03<00:03, 34.31it/s]
#
# Date Pairs:  52%|█████████▎        | 140/270 [00:04<00:03, 34.28it/s]
#
# Date Pairs:  53%|█████████▌        | 144/270 [00:04<00:03, 34.29it/s]
#
# Date Pairs:  55%|█████████▊        | 148/270 [00:04<00:03, 34.36it/s]
#
# Date Pairs:  56%|██████████▏       | 152/270 [00:04<00:03, 34.40it/s]
#
# Date Pairs:  58%|██████████▍       | 156/270 [00:04<00:03, 34.45it/s]
#
# Date Pairs:  59%|██████████▋       | 160/270 [00:04<00:03, 34.38it/s]
#
# Date Pairs:  61%|██████████▉       | 164/270 [00:04<00:03, 34.41it/s]
#
# Date Pairs:  62%|███████████▏      | 168/270 [00:04<00:02, 34.46it/s]
#
# Date Pairs:  64%|███████████▍      | 172/270 [00:05<00:02, 34.37it/s]
#
# Date Pairs:  65%|███████████▋      | 176/270 [00:05<00:02, 34.38it/s]
#
# Date Pairs:  67%|████████████      | 180/270 [00:05<00:02, 34.42it/s]
#
# Date Pairs:  68%|████████████▎     | 184/270 [00:05<00:02, 34.45it/s]
#
# Date Pairs:  70%|████████████▌     | 188/270 [00:05<00:02, 34.49it/s]
#
# Date Pairs:  71%|████████████▊     | 192/270 [00:05<00:02, 34.42it/s]
#
# Date Pairs:  73%|█████████████     | 196/270 [00:05<00:02, 34.28it/s]
#
# Date Pairs:  74%|█████████████▎    | 200/270 [00:05<00:02, 33.25it/s]
#
# Date Pairs:  76%|█████████████▌    | 204/270 [00:05<00:01, 33.47it/s]
#
# Date Pairs:  77%|█████████████▊    | 208/270 [00:06<00:01, 33.66it/s]
#
# Date Pairs:  79%|██████████████▏   | 212/270 [00:06<00:01, 33.95it/s]
#
# Date Pairs:  80%|██████████████▍   | 216/270 [00:06<00:01, 34.04it/s]
#
# Date Pairs:  81%|██████████████▋   | 220/270 [00:06<00:01, 34.12it/s]
#
# Date Pairs:  83%|██████████████▉   | 224/270 [00:06<00:01, 34.09it/s]
#
# Date Pairs:  84%|███████████████▏  | 228/270 [00:06<00:01, 34.03it/s]
#
# Date Pairs:  86%|███████████████▍  | 232/270 [00:06<00:01, 34.04it/s]
#
# Date Pairs:  87%|███████████████▋  | 236/270 [00:06<00:01, 34.00it/s]
#
# Date Pairs:  89%|████████████████  | 240/270 [00:07<00:00, 34.03it/s]
#
# Date Pairs:  90%|████████████████▎ | 244/270 [00:07<00:00, 34.21it/s]
#
# Date Pairs:  92%|████████████████▌ | 248/270 [00:07<00:00, 34.17it/s]
#
# Date Pairs:  93%|████████████████▊ | 252/270 [00:07<00:00, 34.13it/s]
#
# Date Pairs:  95%|█████████████████ | 256/270 [00:07<00:00, 33.93it/s]
#
# Date Pairs:  96%|█████████████████▎| 260/270 [00:07<00:00, 33.82it/s]
#
# Date Pairs:  98%|█████████████████▌| 264/270 [00:07<00:00, 33.84it/s]
#
# Date Pairs: 100%|██████████████████| 270/270 [00:07<00:00, 34.16it/s]
#
#
# Date Pairs:   0%|                             | 0/60 [00:00<?, ?it/s]
#
# Date Pairs:   7%|█▍                   | 4/60 [00:00<00:01, 34.63it/s]
#
# Date Pairs:  13%|██▊                  | 8/60 [00:00<00:01, 34.43it/s]
#
# Date Pairs:  20%|████                | 12/60 [00:00<00:01, 34.30it/s]
#
# Date Pairs:  27%|█████▎              | 16/60 [00:00<00:01, 34.17it/s]
#
# Date Pairs:  33%|██████▋             | 20/60 [00:00<00:01, 34.27it/s]
#
# Date Pairs:  40%|████████            | 24/60 [00:00<00:01, 34.33it/s]
#
# Date Pairs:  47%|█████████▎          | 28/60 [00:00<00:00, 34.31it/s]
#
# Date Pairs:  53%|██████████▋         | 32/60 [00:00<00:00, 34.30it/s]
#
# Date Pairs:  60%|████████████        | 36/60 [00:01<00:00, 34.42it/s]
#
# Date Pairs:  67%|█████████████▎      | 40/60 [00:01<00:00, 34.48it/s]
#
# Date Pairs:  73%|██████████████▋     | 44/60 [00:01<00:00, 34.51it/s]
#
# Date Pairs:  80%|████████████████    | 48/60 [00:01<00:00, 34.35it/s]
#
# Date Pairs:  87%|█████████████████▎  | 52/60 [00:01<00:00, 34.38it/s]
#
# Date Pairs:  93%|██████████████████▋ | 56/60 [00:01<00:00, 34.44it/s]
#
# Date Pairs: 100%|████████████████████| 60/60 [00:01<00:00, 34.39it/s]
#
#
# Date Pairs:   0%|                            | 0/129 [00:00<?, ?it/s]
#
# Date Pairs:   3%|▌                   | 4/129 [00:00<00:03, 33.92it/s]
#
# Date Pairs:   6%|█▏                  | 8/129 [00:00<00:03, 33.80it/s]
#
# Date Pairs:   9%|█▊                 | 12/129 [00:00<00:03, 33.94it/s]
#
# Date Pairs:  12%|██▎                | 16/129 [00:00<00:03, 34.11it/s]
#
# Date Pairs:  16%|██▉                | 20/129 [00:00<00:03, 34.29it/s]
#
# Date Pairs:  19%|███▌               | 24/129 [00:00<00:03, 34.16it/s]
#
# Date Pairs:  22%|████               | 28/129 [00:00<00:02, 34.22it/s]
#
# Date Pairs:  25%|████▋              | 32/129 [00:00<00:02, 34.23it/s]
#
# Date Pairs:  28%|█████▎             | 36/129 [00:01<00:02, 34.19it/s]
#
# Date Pairs:  31%|█████▉             | 40/129 [00:01<00:02, 34.23it/s]
#
# Date Pairs:  34%|██████▍            | 44/129 [00:01<00:02, 34.36it/s]
#
# Date Pairs:  37%|███████            | 48/129 [00:01<00:02, 34.40it/s]
#
# Date Pairs:  40%|███████▋           | 52/129 [00:01<00:02, 34.49it/s]
#
# Date Pairs:  43%|████████▏          | 56/129 [00:01<00:02, 34.39it/s]
#
# Date Pairs:  47%|████████▊          | 60/129 [00:01<00:02, 34.46it/s]
#
# Date Pairs:  50%|█████████▍         | 64/129 [00:01<00:01, 34.19it/s]
#
# Date Pairs:  53%|██████████         | 68/129 [00:01<00:01, 34.08it/s]
#
# Date Pairs:  56%|██████████▌        | 72/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  59%|███████████▏       | 76/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  62%|███████████▊       | 80/129 [00:02<00:01, 33.98it/s]
#
# Date Pairs:  65%|████████████▎      | 84/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  68%|████████████▉      | 88/129 [00:02<00:01, 34.00it/s]
#
# Date Pairs:  71%|█████████████▌     | 92/129 [00:02<00:01, 33.88it/s]
#
# Date Pairs:  74%|██████████████▏    | 96/129 [00:02<00:00, 34.03it/s]
#
# Date Pairs:  78%|█████████████▉    | 100/129 [00:02<00:00, 34.20it/s]
#
# Date Pairs:  81%|██████████████▌   | 104/129 [00:03<00:00, 34.20it/s]
#
# Date Pairs:  84%|███████████████   | 108/129 [00:03<00:00, 34.30it/s]
#
# Date Pairs:  87%|███████████████▋  | 112/129 [00:03<00:00, 34.39it/s]
#
# Date Pairs:  90%|████████████████▏ | 116/129 [00:03<00:00, 34.46it/s]
#
# Date Pairs:  93%|████████████████▋ | 120/129 [00:03<00:00, 34.53it/s]
#
# Date Pairs:  96%|█████████████████▎| 124/129 [00:03<00:00, 34.48it/s]
#
# Date Pairs: 100%|██████████████████| 129/129 [00:03<00:00, 34.23it/s]
#
# 100%|████████████████████████████████| 23/23 [22:21<00:00, 58.35s/it]

# %% [markdown]
# # Preliminary Checks
#
# ## Visualize Spatial Coverage

# %%
dfs = [gpd.read_file(p) for p in tqdm(list(PARAMS.enum_dir.glob('*.geojson')))]

df_ifgs = pd.concat(dfs, axis=0)
# Out:
#   0%|                                                                             | 0/17 [00:00<?, ?it/s]
#   6%|████                                                                 | 1/17 [00:00<00:11,  1.44it/s]
#  12%|████████                                                             | 2/17 [00:01<00:09,  1.63it/s]
#  24%|████████████████▏                                                    | 4/17 [00:01<00:03,  3.43it/s]
#  29%|████████████████████▎                                                | 5/17 [00:01<00:03,  3.66it/s]
#  35%|████████████████████████▎                                            | 6/17 [00:02<00:06,  1.74it/s]
#  41%|████████████████████████████▍                                        | 7/17 [00:03<00:04,  2.30it/s]
#  53%|████████████████████████████████████▌                                | 9/17 [00:03<00:02,  3.27it/s]
#  59%|████████████████████████████████████████                            | 10/17 [00:04<00:02,  2.49it/s]
#  65%|████████████████████████████████████████████                        | 11/17 [00:04<00:03,  1.98it/s]
#  71%|████████████████████████████████████████████████                    | 12/17 [00:05<00:02,  2.43it/s]
#  76%|████████████████████████████████████████████████████                | 13/17 [00:05<00:01,  2.17it/s]
#  82%|████████████████████████████████████████████████████████            | 14/17 [00:06<00:01,  2.06it/s]
#  88%|████████████████████████████████████████████████████████████        | 15/17 [00:06<00:01,  1.82it/s]
#  94%|████████████████████████████████████████████████████████████████    | 16/17 [00:07<00:00,  1.94it/s]
# 100%|████████████████████████████████████████████████████████████████████| 17/17 [00:07<00:00,  2.23it/s]

# %%
# df_ifgs.plot(alpha=.01)

# %% [markdown]
# ## Total IFGs

# %%
df_ifgs.groupby('track_aoi_key')['reference'].count()
# Out:
# track_aoi_key
# track100       1485
# track108       1173
# track115       4160
# track13        3064
# track137      15275
# track144       7952
# track144_1     9198
# track166       2970
# track166_1     5670
# track173       7344
# track35       10670
# track42        1260
# track64        7735
# track64_1      9025
# track71        7360
# track86        2076
# track93        1272
# Name: reference, dtype: int64

# %%
df_ifgs.shape
# Out:
# (97689, 8)

# %% [markdown]
# ## Distribution of Temporal Baselines

# %%
xx = (df_ifgs.reference_date).map(pd.Timestamp) - (df_ifgs.secondary_date).map(pd.Timestamp)

# %%
yy = xx.dt.total_seconds() / (60 * 60 * 24)

# %%
plt.hist(yy)
plt.xlabel('Temporal Baseline (days)')
# Out:
# Text(0.5, 0, 'Temporal Baseline (days)')
